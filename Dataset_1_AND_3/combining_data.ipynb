# %% [markdown]
# ## Patient Class

# %% [markdown]
# ##### Final combination

# %%
import pandas as pd
import json
from collections import defaultdict

# %%
# ============ STEP 1: BUILD THE DICTIONARY ============
def build_patient_dictionary(heart_csv, micro_csv):
    """Build the core patient-admission dictionary structure."""
    
    df1 = pd.read_csv(heart_csv)
    df3 = pd.read_csv(micro_csv)
    
    print(f"Original microbiology shape: {df3.shape}")
    print(f"Original heart shape: {df1.shape}")
    
    # Filter microbiology
    df3_filtered = df3[df3['qc_flag'] != 'QC_FAIL'].copy()
    print(f"After removing QC_FAIL: {df3_filtered.shape}")
    
    patient_dict = {}
    heart_cols = df1.columns.tolist()
    micro_cols = df3_filtered.columns.tolist()
    demo_cols = ['gender', 'age', 'anchor_year', 'dod']
    
    # Process heart dataset
    print("\nProcessing heart dataset...")
    for idx, row in df1.iterrows():
        subject_id = row['subject_id']
        hadm_id = row['hadm_id']
        
        if subject_id not in patient_dict:
            patient_dict[subject_id] = {
                'demographics': {'subject_id': subject_id},
                'admissions': {}
            }
            for col in demo_cols:
                if col in heart_cols:
                    patient_dict[subject_id]['demographics'][col] = row[col]
        
        if hadm_id not in patient_dict[subject_id]['admissions']:
            patient_dict[subject_id]['admissions'][hadm_id] = {
                'hadm_id': hadm_id,
                'heart_notes': [],
                'microbiology': []
            }
        
        cols_to_exclude = ['note_type', 'note_seq', 'charttime'] + demo_cols + ['subject_id', 'hadm_id']
        heart_record = {col: row[col] for col in heart_cols if col not in cols_to_exclude}
        patient_dict[subject_id]['admissions'][hadm_id]['heart_notes'].append(heart_record)
    
    # Process microbiology dataset
    print("Processing microbiology dataset...")
    for idx, row in df3_filtered.iterrows():
        subject_id = row['subject_id']
        hadm_id = row['hadm_id']
        
        if subject_id not in patient_dict:
            patient_dict[subject_id] = {
                'demographics': {'subject_id': subject_id},
                'admissions': {}
            }
        
        if hadm_id not in patient_dict[subject_id]['admissions']:
            patient_dict[subject_id]['admissions'][hadm_id] = {
                'hadm_id': hadm_id,
                'heart_notes': [],
                'microbiology': []
            }
        
        micro_record = {col: row[col] for col in micro_cols if col not in ['subject_id', 'hadm_id']}
        patient_dict[subject_id]['admissions'][hadm_id]['microbiology'].append(micro_record)
    
    return patient_dict

# %%
# ============ STEP 2: PATIENT DATABASE CLASS ============
class PatientDatabase:
    """Wrapper class for patient dictionary with useful query methods."""
    
    def __init__(self, patient_dict):
        self.data = patient_dict
    
    def get_patient(self, subject_id):
        """Get all data for a specific patient."""
        return self.data.get(subject_id, None)
    
    def get_admission(self, subject_id, hadm_id):
        """Get data for a specific admission."""
        patient = self.get_patient(subject_id)
        if patient:
            return patient['admissions'].get(hadm_id, None)
        return None
    
    def get_demographics(self, subject_id):
        """Get demographics for a patient."""
        patient = self.get_patient(subject_id)
        return patient['demographics'] if patient else None
    
    def get_all_admissions(self, subject_id):
        """Get all admissions for a patient."""
        patient = self.get_patient(subject_id)
        return patient['admissions'] if patient else {}
    
    def search_patients(self, **criteria):
        """
        Search patients by criteria.
        Examples:
            search_patients(gender='F')
            search_patients(age_min=60, age_max=80)
            search_patients(has_microbiology=True)
        """
        results = []
        
        for subject_id, patient in self.data.items():
            match = True
            
            # Check demographics criteria
            if 'gender' in criteria:
                if patient['demographics'].get('gender') != criteria['gender']:
                    match = False
            
            if 'age_min' in criteria:
                age = patient['demographics'].get('age')
                if age is None or age < criteria['age_min']:
                    match = False
            
            if 'age_max' in criteria:
                age = patient['demographics'].get('age')
                if age is None or age > criteria['age_max']:
                    match = False
            
            # Check data availability criteria
            if 'has_heart' in criteria and criteria['has_heart']:
                has_heart = any(len(adm['heart_notes']) > 0 for adm in patient['admissions'].values())
                if not has_heart:
                    match = False
            
            if 'has_microbiology' in criteria and criteria['has_microbiology']:
                has_micro = any(len(adm['microbiology']) > 0 for adm in patient['admissions'].values())
                if not has_micro:
                    match = False
            
            if match:
                results.append(subject_id)
        
        return results
    
    def get_statistics(self):
        """Get comprehensive statistics about the database."""
        stats = {
            'total_patients': len(self.data),
            'total_admissions': 0,
            'patients_with_heart': 0,
            'patients_with_microbiology': 0,
            'patients_with_both': 0,
            'admissions_with_both': 0,
            'avg_admissions_per_patient': 0,
            'gender_distribution': defaultdict(int),
            'age_distribution': {'min': None, 'max': None, 'avg': 0}
        }
        
        total_age = 0
        age_count = 0
        ages = []
        
        for patient in self.data.values():
            num_admissions = len(patient['admissions'])
            stats['total_admissions'] += num_admissions
            
            has_heart = any(len(adm['heart_notes']) > 0 for adm in patient['admissions'].values())
            has_micro = any(len(adm['microbiology']) > 0 for adm in patient['admissions'].values())
            
            if has_heart:
                stats['patients_with_heart'] += 1
            if has_micro:
                stats['patients_with_microbiology'] += 1
            if has_heart and has_micro:
                stats['patients_with_both'] += 1
            
            for adm in patient['admissions'].values():
                if len(adm['heart_notes']) > 0 and len(adm['microbiology']) > 0:
                    stats['admissions_with_both'] += 1
            
            # Demographics
            gender = patient['demographics'].get('gender')
            if gender:
                stats['gender_distribution'][gender] += 1
            
            age = patient['demographics'].get('age')
            if age is not None:
                ages.append(age)
                total_age += age
                age_count += 1
        
        if stats['total_patients'] > 0:
            stats['avg_admissions_per_patient'] = stats['total_admissions'] / stats['total_patients']
        
        if ages:
            stats['age_distribution']['min'] = min(ages)
            stats['age_distribution']['max'] = max(ages)
            stats['age_distribution']['avg'] = total_age / age_count
        
        stats['gender_distribution'] = dict(stats['gender_distribution'])
        
        return stats
    
    def export_patient_list(self, subject_ids=None):
        """Export list of patients with key info."""
        if subject_ids is None:
            subject_ids = self.data.keys()
        
        patient_list = []
        for subject_id in subject_ids:
            if subject_id in self.data:
                patient = self.data[subject_id]
                patient_list.append({
                    'subject_id': subject_id,
                    'demographics': patient['demographics'],
                    'num_admissions': len(patient['admissions']),
                    'has_heart': any(len(adm['heart_notes']) > 0 for adm in patient['admissions'].values()),
                    'has_microbiology': any(len(adm['microbiology']) > 0 for adm in patient['admissions'].values())
                })
        
        return patient_list
    
    def save(self, filename='patient_database.json'):
        """Save database to JSON file."""
        with open(filename, 'w') as f:
            json_dict = {str(k): v for k, v in self.data.items()}
            json.dump(json_dict, f, indent=2, default=str)
        print(f"Database saved to '{filename}'")
    
    def get_patient_count(self):
        """Get total number of patients."""
        return len(self.data)
    
    def get_admission_count(self):
        """Get total number of admissions."""
        return sum(len(p['admissions']) for p in self.data.values())

# %%
# ============ USAGE ============
print("Building patient dictionary...")
patient_dict = build_patient_dictionary("heart_diagnoses_1.csv", "microbiology_events_codes_3.csv")

print("\nInitializing PatientDatabase...")
db = PatientDatabase(patient_dict)

print("\nPatientDatabase ready! Use db.method() to query the data.")
# Out:
# Building patient dictionary...
# Original microbiology shape: (15587, 14)
# Original heart shape: (4864, 25)
# After removing QC_FAIL: (14808, 14)
#
# Processing heart dataset...
# Processing microbiology dataset...
#
# Initializing PatientDatabase...
#
# PatientDatabase ready! Use db.method() to query the data.

# %%
print("\n=== DATABASE STATISTICS ===")
stats = db.get_statistics()
for key, value in stats.items():
    print(f"{key}: {value}")

# Saving database
db.save('patient_database.json')
# Out:
# === DATABASE STATISTICS ===
# total_patients: 4679
# total_admissions: 5151
# patients_with_heart: 4392
# patients_with_microbiology: 2572
# patients_with_both: 2285
# admissions_with_both: 2420
# avg_admissions_per_patient: 1.1008762556101732
# gender_distribution: {'F': 533, nan: 3128, 'M': 731}
# age_distribution: {'min': 18.0, 'max': 95.0, 'avg': nan}
# Database saved to 'patient_database.json'

# %%
# Specific patient (10000980)
patient = db.get_patient(10000980)
print(f"Patient data: {patient['demographics']}")
# Out:
# Patient data: {'subject_id': 10000980, 'gender': 'F', 'age': 75.0, 'anchor_year': 2186.0, 'dod': '2193-08-26'}

# %%
# Searching for female patients aged 60-80
female_seniors = db.search_patients(gender='F', age_min=60, age_max=80)
print(f"Found {len(female_seniors)} female patients aged 60-80")
# Out:
# Found 256 female patients aged 60-80

# %%
# Get patients with both datasets
complete_patients = db.search_patients(has_heart=True, has_microbiology=True)
print(f"Patients with complete data: {len(complete_patients)}")
# Out:
# Patients with complete data: 2285

# %%
# Export patient list
patient_list = db.export_patient_list(complete_patients[:10])
print(f"Exported {len(patient_list)} patients")
# Out:
# Exported 10 patients

# %%
all_patients = list(db.data.keys())

# %%
for patient_id, patient in db.data.items():
    print(f"\n===== Patient {patient_id} =====")
    
    admissions = patient.get("admissions", {})
    
    for hadm_id, adm in admissions.items():
        print(f"  Admission {hadm_id}:")
        
        # Loop through everything inside the admission
        for key, records in adm.items():
            # Skip if value is not a list (e.g., timestamps)
            if isinstance(records, list):
                print(f"    {key}: {len(records)} record(s)")
# Out:
# ===== Patient 10000980 =====
#   Admission 29654838:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#   Admission 26913865:
#     heart_notes: 1 record(s)
#     microbiology: 1 record(s)
#
# ===== Patient 10002013 =====
#   Admission 24760295:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#
# ===== Patient 10002155 =====
#   Admission 23822395:
#     heart_notes: 1 record(s)
#     microbiology: 12 record(s)
#
# ===== Patient 10004457 =====
#   Admission 28723315:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#
# ===== Patient 10007058 =====
#   Admission 22954658:
#     heart_notes: 1 record(s)
#     microbiology: 2 record(s)
#
# ===== Patient 10010424 =====
#   Admission 28388172:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#
# ===== Patient 10012343 =====
#   Admission 27658045:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#
# ===== Patient 10013569 =====
#   Admission 22891949:
#     heart_notes: 1 record(s)
#     microbiology: 1 record(s)
#
# ===== Patient 10014651 =====
#   Admission 20051301:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#
# ===== Patient 10017531 =====
#   Admission 20668418:
#     heart_notes: 1 record(s)
#     microbiology: 1 record(s)
#
# ===== Patient 10017886 =====
#   Admission 20015927:
#     heart_notes: 1 record(s)
#     microbiology: 1 record(s)
#
# ===== Patient 10018684 =====
#   Admission 26649049:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#
# ===== Patient 10023117 =====
#   Admission 28872262:
#     heart_notes: 1 record(s)
#     microbiology: 3 record(s)
#
# ===== Patient 10024331 =====
#   Admission 27524226:
#     heart_notes: 1 record(s)
#     microbiology: 3 record(s)
#
# ===== Patient 10024913 =====
#   Admission 27207228:
#     heart_notes: 1 record(s)
#     microbiology: 1 record(s)
#
# ===== Patient 10024982 =====
#   Admission 25153817:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#
# ===== Patient 10025647 =====
#   Admission 28899194:
#     heart_notes: 1 record(s)
#     microbiology: 1 record(s)
#
# ===== Patient 10026263 =====
#   Admission 26565360:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#
# ===== Patient 10035787 =====
#   Admission 29728342:
#     heart_notes: 1 record(s)
#     microbiology: 2 record(s)
#
# ===== Patient 10040025 =====
#   Admission 25384176:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#
# ===== Patient 10044096 =====
#   Admission 27828954:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#
# ===== Patient 10047893 =====
#   Admission 21686524:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#
# ===== Patient 10051074 =====
#   Admission 21350747:
#     heart_notes: 1 record(s)
#     microbiology: 7 record(s)
#
# ===== Patient 10054464 =====
#   Admission 20069204:
#     heart_notes: 1 record(s)
#     microbiology: 1 record(s)
#
# ===== Patient 10055344 =====
#   Admission 29209451:
#     heart_notes: 1 record(s)
#     microbiology: 4 record(s)
#   Admission 29725720:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#
# ===== Patient 10055694 =====
#   Admission 25049824:
#     heart_notes: 1 record(s)
#     microbiology: 6 record(s)
#
# ===== Patient 10058974 =====
#   Admission 21397311:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#
# ===== Patient 10059952 =====
#   Admission 21462829:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#
# ===== Patient 10062617 =====
#   Admission 27056234:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#
# ===== Patient 10063534 =====
#   Admission 26199018:
#     heart_notes: 1 record(s)
#     microbiology: 8 record(s)
#
# ===== Patient 10064049 =====
#   Admission 22000239:
#     heart_notes: 1 record(s)
#     microbiology: 3 record(s)
#
# ===== Patient 10065057 =====
#   Admission 23283867:
#     heart_notes: 1 record(s)
#     microbiology: 4 record(s)
#
# ===== Patient 10066397 =====
#   Admission 26093769:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#
# ===== Patient 10067573 =====
#   Admission 23238723:
#     heart_notes: 1 record(s)
#     microbiology: 1 record(s)
#
# ===== Patient 10070311 =====
#   Admission 22121727:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#
# ===== Patient 10070614 =====
#   Admission 24953436:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#   Admission 21019690:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#
# ===== Patient 10075925 =====
#   Admission 26160109:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#
# ===== Patient 10076616 =====
#   Admission 21934451:
#     heart_notes: 1 record(s)
#     microbiology: 4 record(s)
#
# ===== Patient 10087025 =====
#   Admission 27602831:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#
# ===== Patient 10089244 =====
#   Admission 29469323:
#     heart_notes: 1 record(s)
#     microbiology: 17 record(s)
#
# ===== Patient 10090787 =====
#   Admission 20628099:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#
# ===== Patient 10091747 =====
#   Admission 23611428:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#
# ===== Patient 10091871 =====
#   Admission 26777528:
#     heart_notes: 1 record(s)
#     microbiology: 6 record(s)
#
# ===== Patient 10092171 =====
#   Admission 25201843:
#     heart_notes: 1 record(s)
#     microbiology: 5 record(s)
#
# ===== Patient 10093609 =====
#   Admission 29765478:
#     heart_notes: 1 record(s)
#     microbiology: 4 record(s)
#
# ===== Patient 10094805 =====
#   Admission 21370539:
#     heart_notes: 1 record(s)
#     microbiology: 15 record(s)
#
# ===== Patient 10096420 =====
#   Admission 25396519:
#     heart_notes: 1 record(s)
#     microbiology: 1 record(s)
#
# ===== Patient 10097089 =====
#   Admission 29964590:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#
# ===== Patient 10097612 =====
#   Admission 29104091:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#
# ===== Patient 10099652 =====
#   Admission 28009527:
#     heart_notes: 1 record(s)
#     microbiology: 1 record(s)
#
# ===== Patient 10100652 =====
#   Admission 28408032:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#
# ===== Patient 10104308 =====
#   Admission 22112213:
#     heart_notes: 1 record(s)
#     microbiology: 4 record(s)
#   Admission 24307783:
#     heart_notes: 1 record(s)
#     microbiology: 11 record(s)
#
# ===== Patient 10106244 =====
#   Admission 26713233:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#
# ===== Patient 10108435 =====
#   Admission 29311327:
#     heart_notes: 1 record(s)
#     microbiology: 6 record(s)
#   Admission 26448261:
#     heart_notes: 1 record(s)
#     microbiology: 4 record(s)
#   Admission 23333218:
#     heart_notes: 1 record(s)
#     microbiology: 20 record(s)
#
# ===== Patient 10108868 =====
#   Admission 21396883:
#     heart_notes: 1 record(s)
#     microbiology: 3 record(s)
#
# ===== Patient 10109085 =====
#   Admission 25661234:
#     heart_notes: 1 record(s)
#     microbiology: 10 record(s)
#
# ===== Patient 10109526 =====
#   Admission 27092999:
#     heart_notes: 1 record(s)
#     microbiology: 7 record(s)
#
# ===== Patient 10111614 =====
#   Admission 22951202:
#     heart_notes: 1 record(s)
#     microbiology: 2 record(s)
#
# ===== Patient 10112698 =====
#   Admission 28301505:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#
# ===== Patient 10113926 =====
#   Admission 29815425:
#     heart_notes: 1 record(s)
#     microbiology: 2 record(s)
#
# ===== Patient 10119514 =====
#   Admission 24286743:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#
# ===== Patient 10124346 =====
#   Admission 24026336:
#     heart_notes: 1 record(s)
#     microbiology: 13 record(s)
#
# ===== Patient 10124367 =====
#   Admission 25023894:
#     heart_notes: 1 record(s)
#     microbiology: 4 record(s)
#   Admission 27078967:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#
# ===== Patient 10127936 =====
#   Admission 20688231:
#     heart_notes: 1 record(s)
#     microbiology: 4 record(s)
#
# ===== Patient 10130275 =====
#   Admission 27368633:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#
# ===== Patient 10130937 =====
#   Admission 26669161:
#     heart_notes: 1 record(s)
#     microbiology: 1 record(s)
#
# ===== Patient 10141493 =====
#   Admission 24068236:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#
# ===== Patient 10146603 =====
#   Admission 23552174:
#     heart_notes: 1 record(s)
#     microbiology: 1 record(s)
#
# ===== Patient 10154271 =====
#   Admission 27602007:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#
# ===== Patient 10156269 =====
#   Admission 21303564:
#     heart_notes: 1 record(s)
#     microbiology: 1 record(s)
#
# ===== Patient 10165672 =====
#   Admission 22290954:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#
# ===== Patient 10167691 =====
#   Admission 29515509:
#     heart_notes: 1 record(s)
#     microbiology: 2 record(s)
#
# ===== Patient 10169726 =====
#   Admission 22012406:
#     heart_notes: 1 record(s)
#     microbiology: 8 record(s)
#
# ===== Patient 10171967 =====
#   Admission 29592823:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#
# ===== Patient 10172042 =====
#   Admission 20660191:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#
# ===== Patient 10174935 =====
#   Admission 23150740:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#
# ===== Patient 10177152 =====
#   Admission 20435576:
#     heart_notes: 1 record(s)
#     microbiology: 1 record(s)
#
# ===== Patient 10180134 =====
#   Admission 27497725:
#     heart_notes: 1 record(s)
#     microbiology: 2 record(s)
#
# ===== Patient 10182211 =====
#   Admission 29077579:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#   Admission 21994510:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#
# ===== Patient 10188275 =====
#   Admission 25566836:
#     heart_notes: 1 record(s)
#     microbiology: 3 record(s)
#   Admission 25261717:
#     heart_notes: 1 record(s)
#     microbiology: 2 record(s)
#
# ===== Patient 10188935 =====
#   Admission 22289170:
#     heart_notes: 1 record(s)
#     microbiology: 4 record(s)
#
# ===== Patient 10193428 =====
#   Admission 26652692:
#     heart_notes: 1 record(s)
#     microbiology: 6 record(s)
#
# ===== Patient 10194132 =====
#   Admission 22153963:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#
# ===== Patient 10194610 =====
#   Admission 27525967:
#     heart_notes: 1 record(s)
#     microbiology: 2 record(s)
#
# ===== Patient 10197006 =====
#   Admission 21967982:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#
# ===== Patient 10199560 =====
#   Admission 20334314:
#     heart_notes: 1 record(s)
#     microbiology: 2 record(s)
#
# ===== Patient 10201578 =====
#   Admission 27455104:
#     heart_notes: 1 record(s)
#     microbiology: 4 record(s)
#
# ===== Patient 10203235 =====
#   Admission 20070071:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#   Admission 24203891:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#   Admission 27901592:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#   Admission 28960005:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#
# ===== Patient 10207476 =====
#   Admission 23524758:
#     heart_notes: 1 record(s)
#     microbiology: 2 record(s)
#
# ===== Patient 10216097 =====
#   Admission 23709960:
#     heart_notes: 1 record(s)
#     microbiology: 14 record(s)
#
# ===== Patient 10218214 =====
#   Admission 21344808:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#   Admission 29850297:
#     heart_notes: 1 record(s)
#     microbiology: 16 record(s)
#
# ===== Patient 10220991 =====
#   Admission 26063925:
#     heart_notes: 1 record(s)
#     microbiology: 1 record(s)
#
# ===== Patient 10224335 =====
#   Admission 28418370:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#
# ===== Patient 10227947 =====
#   Admission 29485624:
#     heart_notes: 1 record(s)
#     microbiology: 2 record(s)
#
# ===== Patient 10229025 =====
#   Admission 23454742:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#
# ===== Patient 10230644 =====
#   Admission 27946888:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#
# ===== Patient 10231100 =====
#   Admission 22879976:
#     heart_notes: 1 record(s)
#     microbiology: 4 record(s)
#
# ===== Patient 10232096 =====
#   Admission 21324713:
#     heart_notes: 1 record(s)
#     microbiology: 1 record(s)
#
# ===== Patient 10233845 =====
#   Admission 25863531:
#     heart_notes: 1 record(s)
#     microbiology: 4 record(s)
#
# ===== Patient 10237315 =====
#   Admission 22558185:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#
# ===== Patient 10237677 =====
#   Admission 21434094:
#     heart_notes: 1 record(s)
#     microbiology: 5 record(s)
#
# ===== Patient 10240789 =====
#   Admission 22045808:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#
# ===== Patient 10242353 =====
#   Admission 27610308:
#     heart_notes: 1 record(s)
#     microbiology: 4 record(s)
#
# ===== Patient 10244046 =====
#   Admission 27440644:
#     heart_notes: 1 record(s)
#     microbiology: 16 record(s)
#
# ===== Patient 10246786 =====
#   Admission 21770092:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#
# ===== Patient 10247940 =====
#   Admission 28900426:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#
# ===== Patient 10249381 =====
#   Admission 29963745:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#
# ===== Patient 10250159 =====
#   Admission 23529908:
#     heart_notes: 1 record(s)
#     microbiology: 1 record(s)
#
# ===== Patient 10250582 =====
#   Admission 24957300:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#
# ===== Patient 10253057 =====
#   Admission 22939697:
#     heart_notes: 1 record(s)
#     microbiology: 1 record(s)
#
# ===== Patient 10254844 =====
#   Admission 24542797:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#
# ===== Patient 10257550 =====
#   Admission 20105129:
#     heart_notes: 1 record(s)
#     microbiology: 11 record(s)
#
# ===== Patient 10259667 =====
#   Admission 24389378:
#     heart_notes: 1 record(s)
#     microbiology: 3 record(s)
#
# ===== Patient 10260642 =====
#   Admission 26981835:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#
# ===== Patient 10262728 =====
#   Admission 23315044:
#     heart_notes: 1 record(s)
#     microbiology: 2 record(s)
#
# ===== Patient 10264575 =====
#   Admission 23409188:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#
# ===== Patient 10271338 =====
#   Admission 28626686:
#     heart_notes: 1 record(s)
#     microbiology: 5 record(s)
#
# ===== Patient 10274145 =====
#   Admission 23005773:
#     heart_notes: 1 record(s)
#     microbiology: 52 record(s)
#
# ===== Patient 10274377 =====
#   Admission 29835662:
#     heart_notes: 1 record(s)
#     microbiology: 1 record(s)
#
# ===== Patient 10276723 =====
#   Admission 20320908:
#     heart_notes: 1 record(s)
#     microbiology: 1 record(s)
#
# ===== Patient 10277901 =====
#   Admission 22457836:
#     heart_notes: 1 record(s)
#     microbiology: 1 record(s)
#
# ===== Patient 10278097 =====
#   Admission 20833341:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#
# ===== Patient 10278306 =====
#   Admission 28022798:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#
# ===== Patient 10280267 =====
#   Admission 28165613:
#     heart_notes: 1 record(s)
#     microbiology: 2 record(s)
#
# ===== Patient 10283092 =====
#   Admission 21872519:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#
# ===== Patient 10285427 =====
#   Admission 28941482:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#
# ===== Patient 10287678 =====
#   Admission 26777702:
#     heart_notes: 1 record(s)
#     microbiology: 5 record(s)
#
# ===== Patient 10296643 =====
#   Admission 27101686:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#
# ===== Patient 10297774 =====
#   Admission 27249567:
#     heart_notes: 1 record(s)
#     microbiology: 49 record(s)
#
# ===== Patient 10299002 =====
#   Admission 25552952:
#     heart_notes: 1 record(s)
#     microbiology: 1 record(s)
#
# ===== Patient 10302201 =====
#   Admission 29087677:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#
# ===== Patient 10304606 =====
#   Admission 25220743:
#     heart_notes: 1 record(s)
#     microbiology: 12 record(s)
#
# ===== Patient 10305488 =====
#   Admission 26986783:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#
# ===== Patient 10305856 =====
#   Admission 22485436:
#     heart_notes: 1 record(s)
#     microbiology: 1 record(s)
#
# ===== Patient 10306023 =====
#   Admission 24147094:
#     heart_notes: 1 record(s)
#     microbiology: 2 record(s)
#
# ===== Patient 10306412 =====
#   Admission 25979672:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#
# ===== Patient 10309664 =====
#   Admission 27593295:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#
# ===== Patient 10325287 =====
#   Admission 22278176:
#     heart_notes: 1 record(s)
#     microbiology: 2 record(s)
#
# ===== Patient 10326117 =====
#   Admission 24089994:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#
# ===== Patient 10327840 =====
#   Admission 24584666:
#     heart_notes: 1 record(s)
#     microbiology: 1 record(s)
#
# ===== Patient 10330091 =====
#   Admission 24994937:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#
# ===== Patient 10331862 =====
#   Admission 20976361:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#
# ===== Patient 10337761 =====
#   Admission 25226278:
#     heart_notes: 1 record(s)
#     microbiology: 29 record(s)
#
# ===== Patient 10338643 =====
#   Admission 29680431:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#
# ===== Patient 10345163 =====
#   Admission 24795047:
#     heart_notes: 1 record(s)
#     microbiology: 10 record(s)
#   Admission 22833923:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#
# ===== Patient 10345771 =====
#   Admission 23775355:
#     heart_notes: 1 record(s)
#     microbiology: 6 record(s)
#
# ===== Patient 10347400 =====
#   Admission 22934865:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#
# ===== Patient 10349402 =====
#   Admission 26622844:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#
# ===== Patient 10352192 =====
#   Admission 20704435:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#
# ===== Patient 10352433 =====
#   Admission 23591523:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#
# ===== Patient 10354217 =====
#   Admission 22315422:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#
# ===== Patient 10357013 =====
#   Admission 25245127:
#     heart_notes: 1 record(s)
#     microbiology: 2 record(s)
#
# ===== Patient 10359948 =====
#   Admission 29268419:
#     heart_notes: 1 record(s)
#     microbiology: 9 record(s)
#
# ===== Patient 10362783 =====
#   Admission 22629689:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#
# ===== Patient 10363534 =====
#   Admission 26204870:
#     heart_notes: 1 record(s)
#     microbiology: 4 record(s)
#
# ===== Patient 10364180 =====
#   Admission 29187882:
#     heart_notes: 1 record(s)
#     microbiology: 12 record(s)
#
# ===== Patient 10367718 =====
#   Admission 22363808:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#
# ===== Patient 10368327 =====
#   Admission 27421167:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#
# ===== Patient 10368676 =====
#   Admission 26668083:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#
# ===== Patient 10371715 =====
#   Admission 25829707:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#
# ===== Patient 10388470 =====
#   Admission 29742451:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#
# ===== Patient 10394761 =====
#   Admission 23737808:
#     heart_notes: 1 record(s)
#     microbiology: 5 record(s)
#   Admission 29108031:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#
# ===== Patient 10395897 =====
#   Admission 21348745:
#     heart_notes: 1 record(s)
#     microbiology: 2 record(s)
#
# ===== Patient 10398029 =====
#   Admission 29053367:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#   Admission 26711333:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#
# ===== Patient 10398209 =====
#   Admission 26551658:
#     heart_notes: 1 record(s)
#     microbiology: 3 record(s)
#
# ===== Patient 10407730 =====
#   Admission 29168802:
#     heart_notes: 1 record(s)
#     microbiology: 3 record(s)
#
# ===== Patient 10409536 =====
#   Admission 20422186:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#
# ===== Patient 10417160 =====
#   Admission 27052887:
#     heart_notes: 1 record(s)
#     microbiology: 1 record(s)
#
# ===== Patient 10420050 =====
#   Admission 26573403:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#
# ===== Patient 10422699 =====
#   Admission 26593792:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#
# ===== Patient 10423633 =====
#   Admission 20068195:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#
# ===== Patient 10426775 =====
#   Admission 27444901:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#
# ===== Patient 10427443 =====
#   Admission 26245059:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#
# ===== Patient 10428745 =====
#   Admission 20101651:
#     heart_notes: 1 record(s)
#     microbiology: 2 record(s)
#
# ===== Patient 10438769 =====
#   Admission 23665249:
#     heart_notes: 1 record(s)
#     microbiology: 14 record(s)
#
# ===== Patient 10438951 =====
#   Admission 22568401:
#     heart_notes: 1 record(s)
#     microbiology: 17 record(s)
#
# ===== Patient 10439484 =====
#   Admission 25909616:
#     heart_notes: 1 record(s)
#     microbiology: 1 record(s)
#
# ===== Patient 10444779 =====
#   Admission 28987273:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#
# ===== Patient 10444896 =====
#   Admission 22583942:
#     heart_notes: 1 record(s)
#     microbiology: 1 record(s)
#
# ===== Patient 10447190 =====
#   Admission 26350801:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#
# ===== Patient 10449928 =====
#   Admission 21406053:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#
# ===== Patient 10451487 =====
#   Admission 27193816:
#     heart_notes: 1 record(s)
#     microbiology: 2 record(s)
#
# ===== Patient 10453833 =====
#   Admission 26436374:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#   Admission 29854942:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#
# ===== Patient 10455613 =====
#   Admission 24050094:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#
# ===== Patient 10455855 =====
#   Admission 21613260:
#     heart_notes: 1 record(s)
#     microbiology: 11 record(s)
#
# ===== Patient 10456718 =====
#   Admission 29448358:
#     heart_notes: 1 record(s)
#     microbiology: 1 record(s)
#
# ===== Patient 10459005 =====
#   Admission 25449038:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#   Admission 27652873:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#   Admission 20144923:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#
# ===== Patient 10459488 =====
#   Admission 22157520:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#
# ===== Patient 10462084 =====
#   Admission 25196430:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#
# ===== Patient 10467087 =====
#   Admission 27290760:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#
# ===== Patient 10469413 =====
#   Admission 20882549:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#
# ===== Patient 10473769 =====
#   Admission 28160486:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#
# ===== Patient 10474879 =====
#   Admission 23059839:
#     heart_notes: 1 record(s)
#     microbiology: 3 record(s)
#
# ===== Patient 10488401 =====
#   Admission 22380230:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#
# ===== Patient 10494089 =====
#   Admission 28188842:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#
# ===== Patient 10495960 =====
#   Admission 20186167:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#
# ===== Patient 10496428 =====
#   Admission 26731894:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#
# ===== Patient 10496705 =====
#   Admission 21631400:
#     heart_notes: 1 record(s)
#     microbiology: 4 record(s)
#
# ===== Patient 10498473 =====
#   Admission 28926124:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#
# ===== Patient 10499472 =====
#   Admission 22928676:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#
# ===== Patient 10502838 =====
#   Admission 29965727:
#     heart_notes: 1 record(s)
#     microbiology: 1 record(s)
#
# ===== Patient 10506944 =====
#   Admission 28983382:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#   Admission 23077815:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#
# ===== Patient 10525200 =====
#   Admission 23409627:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#
# ===== Patient 10525376 =====
#   Admission 29961953:
#     heart_notes: 1 record(s)
#     microbiology: 9 record(s)
#
# ===== Patient 10529681 =====
#   Admission 25643357:
#     heart_notes: 1 record(s)
#     microbiology: 1 record(s)
#
# ===== Patient 10533101 =====
#   Admission 24102017:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#
# ===== Patient 10538657 =====
#   Admission 24251211:
#     heart_notes: 1 record(s)
#     microbiology: 11 record(s)
#   Admission 27000935:
#     heart_notes: 1 record(s)
#     microbiology: 1 record(s)
#
# ===== Patient 10547178 =====
#   Admission 26021876:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#
# ===== Patient 10548806 =====
#   Admission 28275579:
#     heart_notes: 1 record(s)
#     microbiology: 1 record(s)
#
# ===== Patient 10549546 =====
#   Admission 26068185:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#
# ===== Patient 10551762 =====
#   Admission 22833696:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#
# ===== Patient 10552468 =====
#   Admission 22878327:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#   Admission 29782895:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#
# ===== Patient 10556849 =====
#   Admission 28113288:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#
# ===== Patient 10557857 =====
#   Admission 27020220:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#
# ===== Patient 10560473 =====
#   Admission 29788759:
#     heart_notes: 1 record(s)
#     microbiology: 2 record(s)
#
# ===== Patient 10561929 =====
#   Admission 21736955:
#     heart_notes: 1 record(s)
#     microbiology: 2 record(s)
#
# ===== Patient 10562309 =====
#   Admission 29741810:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#
# ===== Patient 10565827 =====
#   Admission 26487537:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#
# ===== Patient 10566481 =====
#   Admission 25510413:
#     heart_notes: 1 record(s)
#     microbiology: 2 record(s)
#
# ===== Patient 10570126 =====
#   Admission 20420609:
#     heart_notes: 1 record(s)
#     microbiology: 2 record(s)
#
# ===== Patient 10573359 =====
#   Admission 21603238:
#     heart_notes: 1 record(s)
#     microbiology: 4 record(s)
#
# ===== Patient 10574967 =====
#   Admission 28316724:
#     heart_notes: 1 record(s)
#     microbiology: 1 record(s)
#
# ===== Patient 10575714 =====
#   Admission 21244727:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#
# ===== Patient 10576601 =====
#   Admission 23825389:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#
# ===== Patient 10577266 =====
#   Admission 20722362:
#     heart_notes: 1 record(s)
#     microbiology: 1 record(s)
#
# ===== Patient 10578679 =====
#   Admission 23116251:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#
# ===== Patient 10581311 =====
#   Admission 23815944:
#     heart_notes: 1 record(s)
#     microbiology: 15 record(s)
#
# ===== Patient 10581759 =====
#   Admission 23088729:
#     heart_notes: 1 record(s)
#     microbiology: 2 record(s)
#
# ===== Patient 10586946 =====
#   Admission 25138352:
#     heart_notes: 1 record(s)
#     microbiology: 6 record(s)
#
# ===== Patient 10590766 =====
#   Admission 28560033:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#
# ===== Patient 10594962 =====
#   Admission 24340966:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#
# ===== Patient 10598267 =====
#   Admission 28584593:
#     heart_notes: 1 record(s)
#     microbiology: 3 record(s)
#
# ===== Patient 10599011 =====
#   Admission 27090769:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#
# ===== Patient 10606965 =====
#   Admission 20727689:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#
# ===== Patient 10611307 =====
#   Admission 25029313:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#
# ===== Patient 10612095 =====
#   Admission 26615024:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#
# ===== Patient 10617079 =====
#   Admission 21312674:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#
# ===== Patient 10619615 =====
#   Admission 29614612:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#
# ===== Patient 10621528 =====
#   Admission 22641437:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#
# ===== Patient 10624517 =====
#   Admission 29210743:
#     heart_notes: 1 record(s)
#     microbiology: 1 record(s)
#
# ===== Patient 10625068 =====
#   Admission 28949339:
#     heart_notes: 1 record(s)
#     microbiology: 6 record(s)
#
# ===== Patient 10626538 =====
#   Admission 20715286:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#
# ===== Patient 10627407 =====
#   Admission 25032750:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#
# ===== Patient 10629722 =====
#   Admission 23111609:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#
# ===== Patient 10630336 =====
#   Admission 26771635:
#     heart_notes: 1 record(s)
#     microbiology: 2 record(s)
#
# ===== Patient 10631298 =====
#   Admission 21839567:
#     heart_notes: 1 record(s)
#     microbiology: 9 record(s)
#
# ===== Patient 10633967 =====
#   Admission 27646936:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#
# ===== Patient 10634612 =====
#   Admission 23606477:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#
# ===== Patient 10639500 =====
#   Admission 26565321:
#     heart_notes: 1 record(s)
#     microbiology: 8 record(s)
#   Admission 20794194:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#
# ===== Patient 10640977 =====
#   Admission 24591532:
#     heart_notes: 1 record(s)
#     microbiology: 8 record(s)
#
# ===== Patient 10649183 =====
#   Admission 23940982:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#
# ===== Patient 10649541 =====
#   Admission 23223704:
#     heart_notes: 1 record(s)
#     microbiology: 8 record(s)
#
# ===== Patient 10651616 =====
#   Admission 28300240:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#
# ===== Patient 10653013 =====
#   Admission 26618599:
#     heart_notes: 1 record(s)
#     microbiology: 7 record(s)
#   Admission 29001549:
#     heart_notes: 1 record(s)
#     microbiology: 2 record(s)
#
# ===== Patient 10653589 =====
#   Admission 24817372:
#     heart_notes: 1 record(s)
#     microbiology: 21 record(s)
#
# ===== Patient 10654911 =====
#   Admission 22962348:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#
# ===== Patient 10658431 =====
#   Admission 23926121:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#
# ===== Patient 10661347 =====
#   Admission 22155249:
#     heart_notes: 1 record(s)
#     microbiology: 1 record(s)
#
# ===== Patient 10668732 =====
#   Admission 26363897:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#
# ===== Patient 10669695 =====
#   Admission 23053402:
#     heart_notes: 1 record(s)
#     microbiology: 7 record(s)
#
# ===== Patient 10674538 =====
#   Admission 28960556:
#     heart_notes: 1 record(s)
#     microbiology: 1 record(s)
#
# ===== Patient 10675147 =====
#   Admission 28162856:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#
# ===== Patient 10675468 =====
#   Admission 23790127:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#
# ===== Patient 10676001 =====
#   Admission 29051030:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#
# ===== Patient 10682684 =====
#   Admission 29579074:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#
# ===== Patient 10684247 =====
#   Admission 28430275:
#     heart_notes: 1 record(s)
#     microbiology: 8 record(s)
#
# ===== Patient 10684958 =====
#   Admission 24363434:
#     heart_notes: 1 record(s)
#     microbiology: 1 record(s)
#   Admission 20813028:
#     heart_notes: 1 record(s)
#     microbiology: 47 record(s)
#   Admission 26251383:
#     heart_notes: 1 record(s)
#     microbiology: 2 record(s)
#
# ===== Patient 10687583 =====
#   Admission 26532220:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#
# ===== Patient 10688510 =====
#   Admission 28805457:
#     heart_notes: 1 record(s)
#     microbiology: 11 record(s)
#   Admission 25338406:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#
# ===== Patient 10688859 =====
#   Admission 22250100:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#
# ===== Patient 10691738 =====
#   Admission 26999525:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#
# ===== Patient 10706377 =====
#   Admission 29551518:
#     heart_notes: 1 record(s)
#     microbiology: 7 record(s)
#
# ===== Patient 10706968 =====
#   Admission 22874888:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#
# ===== Patient 10716877 =====
#   Admission 21223015:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#
# ===== Patient 10718572 =====
#   Admission 29584086:
#     heart_notes: 1 record(s)
#     microbiology: 7 record(s)
#
# ===== Patient 10722545 =====
#   Admission 20202359:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#
# ===== Patient 10724345 =====
#   Admission 24201650:
#     heart_notes: 1 record(s)
#     microbiology: 3 record(s)
#
# ===== Patient 10728130 =====
#   Admission 27702113:
#     heart_notes: 1 record(s)
#     microbiology: 1 record(s)
#
# ===== Patient 10739621 =====
#   Admission 22199640:
#     heart_notes: 1 record(s)
#     microbiology: 1 record(s)
#
# ===== Patient 10745249 =====
#   Admission 23917383:
#     heart_notes: 1 record(s)
#     microbiology: 6 record(s)
#
# ===== Patient 10747985 =====
#   Admission 26622857:
#     heart_notes: 1 record(s)
#     microbiology: 3 record(s)
#   Admission 20845971:
#     heart_notes: 1 record(s)
#     microbiology: 1 record(s)
#
# ===== Patient 10750883 =====
#   Admission 23834082:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#
# ===== Patient 10754184 =====
#   Admission 22382948:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#   Admission 21837190:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#
# ===== Patient 10754991 =====
#   Admission 26940500:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#
# ===== Patient 10757917 =====
#   Admission 26211408:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#
# ===== Patient 10758368 =====
#   Admission 22655936:
#     heart_notes: 1 record(s)
#     microbiology: 18 record(s)
#
# ===== Patient 10758974 =====
#   Admission 21950450:
#     heart_notes: 1 record(s)
#     microbiology: 22 record(s)
#
# ===== Patient 10765488 =====
#   Admission 23138723:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#
# ===== Patient 10765746 =====
#   Admission 25386305:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#
# ===== Patient 10766131 =====
#   Admission 27971501:
#     heart_notes: 1 record(s)
#     microbiology: 1 record(s)
#
# ===== Patient 10766996 =====
#   Admission 27142603:
#     heart_notes: 1 record(s)
#     microbiology: 3 record(s)
#
# ===== Patient 10769115 =====
#   Admission 28192020:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#
# ===== Patient 10773163 =====
#   Admission 24065738:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#
# ===== Patient 10778309 =====
#   Admission 23581889:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#
# ===== Patient 10779064 =====
#   Admission 20445698:
#     heart_notes: 1 record(s)
#     microbiology: 11 record(s)
#
# ===== Patient 10781468 =====
#   Admission 27810121:
#     heart_notes: 1 record(s)
#     microbiology: 1 record(s)
#
# ===== Patient 10783054 =====
#   Admission 24032537:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#
# ===== Patient 10783512 =====
#   Admission 27074582:
#     heart_notes: 1 record(s)
#     microbiology: 4 record(s)
#
# ===== Patient 10785214 =====
#   Admission 21784562:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#
# ===== Patient 10786539 =====
#   Admission 29192288:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#
# ===== Patient 10790860 =====
#   Admission 29525186:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#
# ===== Patient 10792714 =====
#   Admission 27521086:
#     heart_notes: 1 record(s)
#     microbiology: 1 record(s)
#
# ===== Patient 10795507 =====
#   Admission 29247508:
#     heart_notes: 1 record(s)
#     microbiology: 1 record(s)
#
# ===== Patient 10796996 =====
#   Admission 26461335:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#
# ===== Patient 10797890 =====
#   Admission 27077912:
#     heart_notes: 1 record(s)
#     microbiology: 1 record(s)
#
# ===== Patient 10799337 =====
#   Admission 27995962:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#   Admission 25535022:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#
# ===== Patient 10801908 =====
#   Admission 20068737:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#   Admission 26625457:
#     heart_notes: 1 record(s)
#     microbiology: 5 record(s)
#
# ===== Patient 10802070 =====
#   Admission 27526169:
#     heart_notes: 1 record(s)
#     microbiology: 9 record(s)
#
# ===== Patient 10802781 =====
#   Admission 27852226:
#     heart_notes: 1 record(s)
#     microbiology: 11 record(s)
#
# ===== Patient 10803096 =====
#   Admission 28708257:
#     heart_notes: 1 record(s)
#     microbiology: 3 record(s)
#
# ===== Patient 10812477 =====
#   Admission 23510852:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#
# ===== Patient 10815687 =====
#   Admission 28291342:
#     heart_notes: 1 record(s)
#     microbiology: 7 record(s)
#
# ===== Patient 10816916 =====
#   Admission 26290158:
#     heart_notes: 1 record(s)
#     microbiology: 1 record(s)
#
# ===== Patient 10818124 =====
#   Admission 26228410:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#
# ===== Patient 10820804 =====
#   Admission 27293781:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#
# ===== Patient 10824982 =====
#   Admission 22817560:
#     heart_notes: 1 record(s)
#     microbiology: 1 record(s)
#
# ===== Patient 10827741 =====
#   Admission 24281895:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#
# ===== Patient 10832862 =====
#   Admission 25249616:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#
# ===== Patient 10834692 =====
#   Admission 28985445:
#     heart_notes: 1 record(s)
#     microbiology: 1 record(s)
#
# ===== Patient 10836215 =====
#   Admission 27911725:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#
# ===== Patient 10838580 =====
#   Admission 22362967:
#     heart_notes: 1 record(s)
#     microbiology: 1 record(s)
#
# ===== Patient 10839017 =====
#   Admission 24158775:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#
# ===== Patient 10839265 =====
#   Admission 22807083:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#
# ===== Patient 10840937 =====
#   Admission 21385532:
#     heart_notes: 1 record(s)
#     microbiology: 2 record(s)
#
# ===== Patient 10841600 =====
#   Admission 22344792:
#     heart_notes: 1 record(s)
#     microbiology: 4 record(s)
#
# ===== Patient 10841633 =====
#   Admission 26237340:
#     heart_notes: 1 record(s)
#     microbiology: 1 record(s)
#
# ===== Patient 10843492 =====
#   Admission 24587417:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#
# ===== Patient 10845539 =====
#   Admission 20776014:
#     heart_notes: 1 record(s)
#     microbiology: 3 record(s)
#
# ===== Patient 10845634 =====
#   Admission 23889408:
#     heart_notes: 1 record(s)
#     microbiology: 3 record(s)
#
# ===== Patient 10848881 =====
#   Admission 26986296:
#     heart_notes: 1 record(s)
#     microbiology: 1 record(s)
#
# ===== Patient 10850692 =====
#   Admission 22583896:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#
# ===== Patient 10851176 =====
#   Admission 20502180:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#
# ===== Patient 10853852 =====
#   Admission 27253226:
#     heart_notes: 1 record(s)
#     microbiology: 1 record(s)
#
# ===== Patient 10855229 =====
#   Admission 29546426:
#     heart_notes: 1 record(s)
#     microbiology: 13 record(s)
#
# ===== Patient 10855911 =====
#   Admission 28959020:
#     heart_notes: 1 record(s)
#     microbiology: 1 record(s)
#
# ===== Patient 10859320 =====
#   Admission 26652072:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#   Admission 21198754:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#
# ===== Patient 10861668 =====
#   Admission 29950356:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#
# ===== Patient 10866696 =====
#   Admission 26194105:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#
# ===== Patient 10867166 =====
#   Admission 22308116:
#     heart_notes: 1 record(s)
#     microbiology: 13 record(s)
#
# ===== Patient 10872563 =====
#   Admission 29162538:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#
# ===== Patient 10874416 =====
#   Admission 27639353:
#     heart_notes: 1 record(s)
#     microbiology: 4 record(s)
#
# ===== Patient 10874692 =====
#   Admission 20786973:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#   Admission 28648396:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#
# ===== Patient 10876550 =====
#   Admission 23981116:
#     heart_notes: 1 record(s)
#     microbiology: 1 record(s)
#
# ===== Patient 10881532 =====
#   Admission 24535431:
#     heart_notes: 1 record(s)
#     microbiology: 1 record(s)
#
# ===== Patient 10885902 =====
#   Admission 20949419:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#
# ===== Patient 10891332 =====
#   Admission 25972039:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#
# ===== Patient 10895149 =====
#   Admission 29246943:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#
# ===== Patient 10895795 =====
#   Admission 24268007:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#
# ===== Patient 10896351 =====
#   Admission 26974419:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#
# ===== Patient 10901396 =====
#   Admission 27098000:
#     heart_notes: 1 record(s)
#     microbiology: 9 record(s)
#
# ===== Patient 10906758 =====
#   Admission 24010879:
#     heart_notes: 1 record(s)
#     microbiology: 18 record(s)
#
# ===== Patient 10907139 =====
#   Admission 21048527:
#     heart_notes: 1 record(s)
#     microbiology: 1 record(s)
#
# ===== Patient 10907576 =====
#   Admission 21823470:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#
# ===== Patient 10908710 =====
#   Admission 20405868:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#
# ===== Patient 10909653 =====
#   Admission 22274475:
#     heart_notes: 1 record(s)
#     microbiology: 25 record(s)
#
# ===== Patient 10913302 =====
#   Admission 25374622:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#
# ===== Patient 10914408 =====
#   Admission 24882312:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#
# ===== Patient 10914662 =====
#   Admission 24770135:
#     heart_notes: 1 record(s)
#     microbiology: 4 record(s)
#
# ===== Patient 10914774 =====
#   Admission 22719639:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#
# ===== Patient 10915871 =====
#   Admission 25281443:
#     heart_notes: 1 record(s)
#     microbiology: 1 record(s)
#
# ===== Patient 10917306 =====
#   Admission 27354830:
#     heart_notes: 1 record(s)
#     microbiology: 2 record(s)
#
# ===== Patient 10917546 =====
#   Admission 26286116:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#
# ===== Patient 10918768 =====
#   Admission 20161424:
#     heart_notes: 1 record(s)
#     microbiology: 6 record(s)
#
# ===== Patient 10919141 =====
#   Admission 27417512:
#     heart_notes: 1 record(s)
#     microbiology: 2 record(s)
#   Admission 29610260:
#     heart_notes: 1 record(s)
#     microbiology: 1 record(s)
#   Admission 20507870:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#
# ===== Patient 10920734 =====
#   Admission 20090300:
#     heart_notes: 1 record(s)
#     microbiology: 1 record(s)
#
# ===== Patient 10928012 =====
#   Admission 28155061:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#
# ===== Patient 10928921 =====
#   Admission 22092144:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#
# ===== Patient 10929797 =====
#   Admission 22603065:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#
# ===== Patient 10930844 =====
#   Admission 27035905:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#
# ===== Patient 10931276 =====
#   Admission 25586233:
#     heart_notes: 1 record(s)
#     microbiology: 6 record(s)
#
# ===== Patient 10933538 =====
#   Admission 29958000:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#
# ===== Patient 10935586 =====
#   Admission 27974702:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#
# ===== Patient 10942675 =====
#   Admission 25882211:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#
# ===== Patient 10945859 =====
#   Admission 24557271:
#     heart_notes: 1 record(s)
#     microbiology: 2 record(s)
#
# ===== Patient 10947173 =====
#   Admission 27700357:
#     heart_notes: 1 record(s)
#     microbiology: 17 record(s)
#
# ===== Patient 10947401 =====
#   Admission 22714143:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#
# ===== Patient 10951680 =====
#   Admission 20525869:
#     heart_notes: 1 record(s)
#     microbiology: 4 record(s)
#
# ===== Patient 10955123 =====
#   Admission 22559209:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#
# ===== Patient 10955958 =====
#   Admission 22889633:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#   Admission 27312414:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#
# ===== Patient 10956814 =====
#   Admission 29453246:
#     heart_notes: 1 record(s)
#     microbiology: 3 record(s)
#
# ===== Patient 10956924 =====
#   Admission 25007225:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#
# ===== Patient 10957591 =====
#   Admission 23934309:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#
# ===== Patient 10957880 =====
#   Admission 26345131:
#     heart_notes: 1 record(s)
#     microbiology: 13 record(s)
#
# ===== Patient 10958187 =====
#   Admission 28815208:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#
# ===== Patient 10966765 =====
#   Admission 22688717:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#
# ===== Patient 10969205 =====
#   Admission 26523233:
#     heart_notes: 1 record(s)
#     microbiology: 2 record(s)
#
# ===== Patient 10970125 =====
#   Admission 26040442:
#     heart_notes: 1 record(s)
#     microbiology: 14 record(s)
#
# ===== Patient 10974265 =====
#   Admission 26913827:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#
# ===== Patient 10975446 =====
#   Admission 24250750:
#     heart_notes: 1 record(s)
#     microbiology: 1 record(s)
#
# ===== Patient 10976281 =====
#   Admission 21549408:
#     heart_notes: 1 record(s)
#     microbiology: 3 record(s)
#
# ===== Patient 10977846 =====
#   Admission 24469091:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#
# ===== Patient 10984580 =====
#   Admission 26810040:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#
# ===== Patient 10985522 =====
#   Admission 26484540:
#     heart_notes: 1 record(s)
#     microbiology: 22 record(s)
#
# ===== Patient 10986871 =====
#   Admission 23849391:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#
# ===== Patient 10991358 =====
#   Admission 28645126:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#
# ===== Patient 10995687 =====
#   Admission 23882717:
#     heart_notes: 1 record(s)
#     microbiology: 1 record(s)
#
# ===== Patient 10996235 =====
#   Admission 23388997:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#
# ===== Patient 10998731 =====
#   Admission 20736781:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#
# ===== Patient 11000920 =====
#   Admission 23482032:
#     heart_notes: 1 record(s)
#     microbiology: 1 record(s)
#
# ===== Patient 11006152 =====
#   Admission 21276570:
#     heart_notes: 1 record(s)
#     microbiology: 2 record(s)
#
# ===== Patient 11006886 =====
#   Admission 29398136:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#
# ===== Patient 11009545 =====
#   Admission 24226641:
#     heart_notes: 1 record(s)
#     microbiology: 2 record(s)
#
# ===== Patient 11012243 =====
#   Admission 22970251:
#     heart_notes: 1 record(s)
#     microbiology: 1 record(s)
#
# ===== Patient 11012399 =====
#   Admission 27809185:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#
# ===== Patient 11013775 =====
#   Admission 28354976:
#     heart_notes: 1 record(s)
#     microbiology: 0 record(s)
#
# ===== Patient 11014579 =====
#   Admission 29966957:
#     heart_notes: 1 record(s)
# ...
#     heart_notes: 0 record(s)
#     microbiology: 1 record(s)
#
# ===== Patient 19997517 =====
#   Admission 23524758.0:
#     heart_notes: 0 record(s)
#     microbiology: 1 record(s)
#
# ===== Patient 19997518 =====
#   Admission 22911781.0:
#     heart_notes: 0 record(s)
#     microbiology: 1 record(s)
#
# ===== Patient 19997519 =====
#   Admission 23244074.0:
#     heart_notes: 0 record(s)
#     microbiology: 1 record(s)
#
# ===== Patient 19997520 =====
#   Admission 27576329.0:
#     heart_notes: 0 record(s)
#     microbiology: 1 record(s)
#
# ===== Patient 19997521 =====
#   Admission 23026690.0:
#     heart_notes: 0 record(s)
#     microbiology: 1 record(s)
#
# ===== Patient 19997522 =====
#   Admission 28407258.0:
#     heart_notes: 0 record(s)
#     microbiology: 1 record(s)
#
# ===== Patient 19997523 =====
#   Admission 28516431.0:
#     heart_notes: 0 record(s)
#     microbiology: 1 record(s)
#
# ===== Patient 19997524 =====
#   Admission 22893907.0:
#     heart_notes: 0 record(s)
#     microbiology: 1 record(s)
#
# ===== Patient 19997525 =====
#   Admission 29136206.0:
#     heart_notes: 0 record(s)
#     microbiology: 1 record(s)
#
# ===== Patient 19997526 =====
#   Admission 24537373.0:
#     heart_notes: 0 record(s)
#     microbiology: 1 record(s)
#
# ===== Patient 19997527 =====
#   Admission 26629472.0:
#     heart_notes: 0 record(s)
#     microbiology: 1 record(s)
#
# ===== Patient 19997528 =====
#   Admission 28472002.0:
#     heart_notes: 0 record(s)
#     microbiology: 1 record(s)
#
# ===== Patient 19997529 =====
#   Admission 24520368.0:
#     heart_notes: 0 record(s)
#     microbiology: 1 record(s)
#
# ===== Patient 19997530 =====
#   Admission 22254526.0:
#     heart_notes: 0 record(s)
#     microbiology: 1 record(s)
#
# ===== Patient 19997533 =====
#   Admission 28115408.0:
#     heart_notes: 0 record(s)
#     microbiology: 1 record(s)
#
# ===== Patient 19997534 =====
#   Admission 21323449.0:
#     heart_notes: 0 record(s)
#     microbiology: 1 record(s)
#
# ===== Patient 19997535 =====
#   Admission 26700619.0:
#     heart_notes: 0 record(s)
#     microbiology: 1 record(s)
#
# ===== Patient 19997536 =====
#   Admission 20624446.0:
#     heart_notes: 0 record(s)
#     microbiology: 1 record(s)
#
# ===== Patient 19997537 =====
#   Admission 20811163.0:
#     heart_notes: 0 record(s)
#     microbiology: 1 record(s)
#
# ===== Patient 19997538 =====
#   Admission 29226245.0:
#     heart_notes: 0 record(s)
#     microbiology: 1 record(s)
#
# ===== Patient 19997539 =====
#   Admission 24347414.0:
#     heart_notes: 0 record(s)
#     microbiology: 1 record(s)
#
# ===== Patient 19997540 =====
#   Admission 23281464.0:
#     heart_notes: 0 record(s)
#     microbiology: 1 record(s)
#
# ===== Patient 19997542 =====
#   Admission 26278797.0:
#     heart_notes: 0 record(s)
#     microbiology: 1 record(s)
#
# ===== Patient 19997543 =====
#   Admission 27614872.0:
#     heart_notes: 0 record(s)
#     microbiology: 1 record(s)
#
# ===== Patient 19997544 =====
#   Admission 20205373.0:
#     heart_notes: 0 record(s)
#     microbiology: 1 record(s)
#
# ===== Patient 19997545 =====
#   Admission 26941902.0:
#     heart_notes: 0 record(s)
#     microbiology: 1 record(s)
#
# ===== Patient 19997547 =====
#   Admission 24301961.0:
#     heart_notes: 0 record(s)
#     microbiology: 1 record(s)
#
# ===== Patient 19997548 =====
#   Admission 25558049.0:
#     heart_notes: 0 record(s)
#     microbiology: 1 record(s)
#
# ===== Patient 19997549 =====
#   Admission 21945592.0:
#     heart_notes: 0 record(s)
#     microbiology: 1 record(s)
#
# ===== Patient 19997550 =====
#   Admission 25087116.0:
#     heart_notes: 0 record(s)
#     microbiology: 1 record(s)
#
# ===== Patient 19997552 =====
#   Admission 25391962.0:
#     heart_notes: 0 record(s)
#     microbiology: 1 record(s)
#
# ===== Patient 19997553 =====
#   Admission 23482032.0:
#     heart_notes: 0 record(s)
#     microbiology: 1 record(s)
#
# ===== Patient 19997554 =====
#   Admission 29861589.0:
#     heart_notes: 0 record(s)
#     microbiology: 1 record(s)
#
# ===== Patient 19997555 =====
#   Admission 24999579.0:
#     heart_notes: 0 record(s)
#     microbiology: 1 record(s)
#
# ===== Patient 19997556 =====
#   Admission 28516431.0:
#     heart_notes: 0 record(s)
#     microbiology: 1 record(s)
#
# ===== Patient 19997557 =====
#   Admission 22474874.0:
#     heart_notes: 0 record(s)
#     microbiology: 1 record(s)
#
# ===== Patient 19997558 =====
#   Admission 25635384.0:
#     heart_notes: 0 record(s)
#     microbiology: 1 record(s)
#
# ===== Patient 19997560 =====
#   Admission 20901471.0:
#     heart_notes: 0 record(s)
#     microbiology: 1 record(s)
#
# ===== Patient 19997561 =====
#   Admission 29970039.0:
#     heart_notes: 0 record(s)
#     microbiology: 1 record(s)
#
# ===== Patient 19997562 =====
#   Admission 28527270.0:
#     heart_notes: 0 record(s)
#     microbiology: 1 record(s)
#
# ===== Patient 19997563 =====
#   Admission 20643295.0:
#     heart_notes: 0 record(s)
#     microbiology: 1 record(s)
#
# ===== Patient 19997564 =====
#   Admission 26343667.0:
#     heart_notes: 0 record(s)
#     microbiology: 1 record(s)
#
# ===== Patient 19997565 =====
#   Admission 24347414.0:
#     heart_notes: 0 record(s)
#     microbiology: 1 record(s)
#
# ===== Patient 19997566 =====
#   Admission 29884826.0:
#     heart_notes: 0 record(s)
#     microbiology: 1 record(s)
#
# ===== Patient 19997567 =====
#   Admission 23351074.0:
#     heart_notes: 0 record(s)
#     microbiology: 1 record(s)
#
# ===== Patient 19997568 =====
#   Admission 24026336.0:
#     heart_notes: 0 record(s)
#     microbiology: 1 record(s)
#
# ===== Patient 19997569 =====
#   Admission 26484540.0:
#     heart_notes: 0 record(s)
#     microbiology: 1 record(s)
#
# ===== Patient 19997570 =====
#   Admission 25021674.0:
#     heart_notes: 0 record(s)
#     microbiology: 1 record(s)
#
# ===== Patient 19997571 =====
#   Admission 29452969.0:
#     heart_notes: 0 record(s)
#     microbiology: 1 record(s)
#
# ===== Patient 19997572 =====
#   Admission 24341616.0:
#     heart_notes: 0 record(s)
#     microbiology: 1 record(s)
#
# ===== Patient 19997573 =====
#   Admission 21845389.0:
#     heart_notes: 0 record(s)
#     microbiology: 1 record(s)
#
# ===== Patient 19997574 =====
#   Admission 20541212.0:
#     heart_notes: 0 record(s)
#     microbiology: 1 record(s)
#
# ===== Patient 19997575 =====
#   Admission 24309048.0:
#     heart_notes: 0 record(s)
#     microbiology: 1 record(s)
#
# ===== Patient 19997576 =====
#   Admission 29241595.0:
#     heart_notes: 0 record(s)
#     microbiology: 1 record(s)
#
# ===== Patient 19997577 =====
#   Admission 20379661.0:
#     heart_notes: 0 record(s)
#     microbiology: 1 record(s)
#
# ===== Patient 19997578 =====
#   Admission 20449585.0:
#     heart_notes: 0 record(s)
#     microbiology: 1 record(s)
#
# ===== Patient 19997579 =====
#   Admission 25722359.0:
#     heart_notes: 0 record(s)
#     microbiology: 1 record(s)
#
# ===== Patient 19997580 =====
#   Admission 26976095.0:
#     heart_notes: 0 record(s)
#     microbiology: 1 record(s)
#
# ===== Patient 19997581 =====
#   Admission 23972251.0:
#     heart_notes: 0 record(s)
#     microbiology: 1 record(s)
#
# ===== Patient 19997583 =====
#   Admission 20683654.0:
#     heart_notes: 0 record(s)
#     microbiology: 1 record(s)
#
# ===== Patient 19997584 =====
#   Admission 25187270.0:
#     heart_notes: 0 record(s)
#     microbiology: 1 record(s)
#
# ===== Patient 19997585 =====
#   Admission 23788729.0:
#     heart_notes: 0 record(s)
#     microbiology: 1 record(s)
#
# ===== Patient 19997587 =====
#   Admission 25568984.0:
#     heart_notes: 0 record(s)
#     microbiology: 1 record(s)
#
# ===== Patient 19997588 =====
#   Admission 21332395.0:
#     heart_notes: 0 record(s)
#     microbiology: 1 record(s)
#
# ===== Patient 19997589 =====
#   Admission 24695678.0:
#     heart_notes: 0 record(s)
#     microbiology: 1 record(s)
#
# ===== Patient 19997590 =====
#   Admission 27454409.0:
#     heart_notes: 0 record(s)
#     microbiology: 1 record(s)
#
# ===== Patient 19997591 =====
#   Admission 23262869.0:
#     heart_notes: 0 record(s)
#     microbiology: 1 record(s)
#
# ===== Patient 19997592 =====
#   Admission 26327362.0:
#     heart_notes: 0 record(s)
#     microbiology: 1 record(s)
#
# ===== Patient 19997593 =====
#   Admission 24567210.0:
#     heart_notes: 0 record(s)
#     microbiology: 1 record(s)
#
# ===== Patient 19997594 =====
#   Admission 22991415.0:
#     heart_notes: 0 record(s)
#     microbiology: 1 record(s)
#
# ===== Patient 19997595 =====
#   Admission 20357170.0:
#     heart_notes: 0 record(s)
#     microbiology: 1 record(s)
#
# ===== Patient 19997596 =====
#   Admission 28016813.0:
#     heart_notes: 0 record(s)
#     microbiology: 1 record(s)
#
# ===== Patient 19997597 =====
#   Admission 24187156.0:
#     heart_notes: 0 record(s)
#     microbiology: 1 record(s)
#
# ===== Patient 19997598 =====
#   Admission 29241595.0:
#     heart_notes: 0 record(s)
#     microbiology: 1 record(s)
#
# ===== Patient 19997600 =====
#   Admission 22598312.0:
#     heart_notes: 0 record(s)
#     microbiology: 1 record(s)
#
# ===== Patient 19997601 =====
#   Admission 22897791.0:
#     heart_notes: 0 record(s)
#     microbiology: 1 record(s)
#
# ===== Patient 19997602 =====
#   Admission 23262869.0:
#     heart_notes: 0 record(s)
#     microbiology: 1 record(s)
#
# ===== Patient 19997603 =====
#   Admission 28161060.0:
#     heart_notes: 0 record(s)
#     microbiology: 1 record(s)
#
# ===== Patient 19997604 =====
#   Admission 28963073.0:
#     heart_notes: 0 record(s)
#     microbiology: 1 record(s)
#
# ===== Patient 19997605 =====
#   Admission 21549408.0:
#     heart_notes: 0 record(s)
#     microbiology: 1 record(s)
#
# ===== Patient 19997606 =====
#   Admission 27431159.0:
#     heart_notes: 0 record(s)
#     microbiology: 1 record(s)
#
# ===== Patient 19997607 =====
#   Admission 29546426.0:
#     heart_notes: 0 record(s)
#     microbiology: 1 record(s)
#
# ===== Patient 19997608 =====
#   Admission 24586212.0:
#     heart_notes: 0 record(s)
#     microbiology: 1 record(s)
#
# ===== Patient 19997609 =====
#   Admission 22337826.0:
#     heart_notes: 0 record(s)
#     microbiology: 1 record(s)
#
# ===== Patient 19997610 =====
#   Admission 28416355.0:
#     heart_notes: 0 record(s)
#     microbiology: 1 record(s)
#
# ===== Patient 19997611 =====
#   Admission 28161060.0:
#     heart_notes: 0 record(s)
#     microbiology: 1 record(s)
#
# ===== Patient 19997612 =====
#   Admission 22043044.0:
#     heart_notes: 0 record(s)
#     microbiology: 1 record(s)
#
# ===== Patient 19997613 =====
#   Admission 26523773.0:
#     heart_notes: 0 record(s)
#     microbiology: 1 record(s)
#
# ===== Patient 19997614 =====
#   Admission 24954255.0:
#     heart_notes: 0 record(s)
#     microbiology: 1 record(s)
#
# ===== Patient 19997615 =====
#   Admission 29278627.0:
#     heart_notes: 0 record(s)
#     microbiology: 1 record(s)
#
# ===== Patient 19997616 =====
#   Admission 22719264.0:
#     heart_notes: 0 record(s)
#     microbiology: 1 record(s)
#
# ===== Patient 19997617 =====
#   Admission 26622857.0:
#     heart_notes: 0 record(s)
#     microbiology: 1 record(s)
#
# ===== Patient 19997618 =====
#   Admission 27094900.0:
#     heart_notes: 0 record(s)
#     microbiology: 1 record(s)
#
# ===== Patient 19997619 =====
#   Admission 21548181.0:
#     heart_notes: 0 record(s)
#     microbiology: 1 record(s)
#
# ===== Patient 19997620 =====
#   Admission 27078182.0:
#     heart_notes: 0 record(s)
#     microbiology: 1 record(s)
#
# ===== Patient 19997621 =====
#   Admission 25138352.0:
#     heart_notes: 0 record(s)
#     microbiology: 1 record(s)
#
# ===== Patient 19997622 =====
#   Admission 24499400.0:
#     heart_notes: 0 record(s)
#     microbiology: 1 record(s)
#
# ===== Patient 19997623 =====
#   Admission 23954269.0:
#     heart_notes: 0 record(s)
#     microbiology: 1 record(s)
#
# ===== Patient 19997624 =====
#   Admission 21633959.0:
#     heart_notes: 0 record(s)
#     microbiology: 1 record(s)
#
# ===== Patient 19997625 =====
#   Admission 28960237.0:
#     heart_notes: 0 record(s)
#     microbiology: 1 record(s)
#
# ===== Patient 19997626 =====
#   Admission 20724148.0:
#     heart_notes: 0 record(s)
#     microbiology: 1 record(s)
#
# ===== Patient 19997627 =====
#   Admission 23026690.0:
#     heart_notes: 0 record(s)
#     microbiology: 1 record(s)
#
# ===== Patient 19997628 =====
#   Admission 24998396.0:
#     heart_notes: 0 record(s)
#     microbiology: 1 record(s)
#
# ===== Patient 19997629 =====
#   Admission 24147653.0:
#     heart_notes: 0 record(s)
#     microbiology: 1 record(s)
#
# ===== Patient 19997630 =====
#   Admission 25744822.0:
#     heart_notes: 0 record(s)
#     microbiology: 1 record(s)
#
# ===== Patient 19997631 =====
#   Admission 20097155.0:
#     heart_notes: 0 record(s)
#     microbiology: 1 record(s)
#
# ===== Patient 19997632 =====
#   Admission 22183676.0:
#     heart_notes: 0 record(s)
#     microbiology: 1 record(s)
#
# ===== Patient 19997633 =====
#   Admission 29090337.0:
#     heart_notes: 0 record(s)
#     microbiology: 1 record(s)
#
# ===== Patient 19997634 =====
#   Admission 23005773.0:
#     heart_notes: 0 record(s)
#     microbiology: 1 record(s)
#
# ===== Patient 19997635 =====
#   Admission 22761347.0:
#     heart_notes: 0 record(s)
#     microbiology: 1 record(s)
#
# ===== Patient 19997636 =====
#   Admission 23113259.0:
#     heart_notes: 0 record(s)
#     microbiology: 1 record(s)
#
# ===== Patient 19997637 =====
#   Admission 22856631.0:
#     heart_notes: 0 record(s)
#     microbiology: 1 record(s)
#
# ===== Patient 19997638 =====
#   Admission 28666814.0:
#     heart_notes: 0 record(s)
#     microbiology: 1 record(s)
#
# ===== Patient 19997639 =====
#   Admission 28912145.0:
#     heart_notes: 0 record(s)
#     microbiology: 1 record(s)
#
# ===== Patient 19997641 =====
#   Admission 25281443.0:
#     heart_notes: 0 record(s)
#     microbiology: 1 record(s)
#
# ===== Patient 19997642 =====
#   Admission 27003370.0:
#     heart_notes: 0 record(s)
#     microbiology: 1 record(s)
#
# ===== Patient 19997643 =====
#   Admission 29241519.0:
#     heart_notes: 0 record(s)
#     microbiology: 1 record(s)
#
# ===== Patient 19997644 =====
#   Admission 27317344.0:
#     heart_notes: 0 record(s)
#     microbiology: 1 record(s)
#
# ===== Patient 19997645 =====
#   Admission 28808203.0:
#     heart_notes: 0 record(s)
#     microbiology: 1 record(s)
#
# ===== Patient 19997646 =====
#   Admission 24515135.0:
#     heart_notes: 0 record(s)
#     microbiology: 1 record(s)
#
# ===== Patient 19997647 =====
#   Admission 21044674.0:
#     heart_notes: 0 record(s)
#     microbiology: 1 record(s)
#
# ===== Patient 19997648 =====
#   Admission 23970959.0:
#     heart_notes: 0 record(s)
#     microbiology: 1 record(s)
#
# ===== Patient 19997650 =====
#   Admission 25744822.0:
#     heart_notes: 0 record(s)
#     microbiology: 1 record(s)
#
# ===== Patient 19997651 =====
#   Admission 20587701.0:
#     heart_notes: 0 record(s)
#     microbiology: 1 record(s)
#
# ===== Patient 19997652 =====
#   Admission 27094900.0:
#     heart_notes: 0 record(s)
#     microbiology: 1 record(s)
#
# ===== Patient 19997653 =====
#   Admission 24912593.0:
#     heart_notes: 0 record(s)
#     microbiology: 1 record(s)
#
# ===== Patient 19997654 =====
#   Admission 28279177.0:
#     heart_notes: 0 record(s)
#     microbiology: 1 record(s)
#
# ===== Patient 19997655 =====
#   Admission 29937885.0:
#     heart_notes: 0 record(s)
#     microbiology: 1 record(s)
#
# ===== Patient 19997656 =====
#   Admission 28739310.0:
#     heart_notes: 0 record(s)
#     microbiology: 1 record(s)
#
# ===== Patient 19997657 =====
#   Admission 26908225.0:
#     heart_notes: 0 record(s)
#     microbiology: 1 record(s)
#
# ===== Patient 19997658 =====
#   Admission 20431903.0:
#     heart_notes: 0 record(s)
#     microbiology: 1 record(s)
#
# ===== Patient 19997659 =====
#   Admission 24351693.0:
#     heart_notes: 0 record(s)
#     microbiology: 1 record(s)
#
# ===== Patient 19997660 =====
#   Admission 20374585.0:
#     heart_notes: 0 record(s)
#     microbiology: 1 record(s)
#
# ===== Patient 19997661 =====
#   Admission 25968240.0:
#     heart_notes: 0 record(s)
#     microbiology: 1 record(s)
#
# ===== Patient 19997662 =====
#   Admission 29338106.0:
#     heart_notes: 0 record(s)
#     microbiology: 1 record(s)
#
# ===== Patient 19997663 =====
#   Admission 20511836.0:
#     heart_notes: 0 record(s)
#     microbiology: 1 record(s)
#
# ===== Patient 19997664 =====
#   Admission 25289714.0:
#     heart_notes: 0 record(s)
#     microbiology: 1 record(s)
#
# ===== Patient 19997665 =====
#   Admission 26052266.0:
#     heart_notes: 0 record(s)
#     microbiology: 1 record(s)
#
# ===== Patient 19997666 =====
#   Admission 24256422.0:
#     heart_notes: 0 record(s)
#     microbiology: 1 record(s)
#
# ===== Patient 19997668 =====
#   Admission 20329436.0:
#     heart_notes: 0 record(s)
#     microbiology: 1 record(s)
#
# ===== Patient 19997669 =====
#   Admission 28219199.0:
#     heart_notes: 0 record(s)
#     microbiology: 1 record(s)

# %% [markdown]
# ---

# %% [markdown]
# <hr>
# <p style="font-size:60px; text-align:center;">FIN</p>
# <hr>

# %% [markdown]
# ---

# %% [markdown]
# ## SafeGuard Code

# %%
import pandas as pd
import json

# Read the datasets
df3 = pd.read_csv("microbiology_events_codes_3.csv")
df1 = pd.read_csv("heart_diagnoses_1.csv")

print(f"Original microbiology shape: {df3.shape}")
print(f"Original heart shape: {df1.shape}")

# ============ MICROBIOLOGY PROCESSING ============
df3_filtered = df3[df3['qc_flag'] != 'QC_FAIL'].copy()
print(f"After removing QC_FAIL: {df3_filtered.shape}")

def create_subject_dict(df):
    """Creates dictionary with subject_id as keys, microbiology data as lists of lists."""
    subject_dict = {}
    grouped = df.groupby('subject_id')
    
    for subject_id, group in grouped:
        rows_as_lists = group.values.tolist()
        subject_dict[subject_id] = {
            "microbiology": rows_as_lists
        }
    
    return subject_dict

# Create the dictionary with microbiology data
microbiology_dict = create_subject_dict(df3_filtered)
print(f"Unique subjects in microbiology: {len(microbiology_dict)}")

# ============ HEART DATASET PROCESSING ============
columns_to_drop = ['note_type', 'note_seq', 'charttime']
existing_cols_to_drop = [col for col in columns_to_drop if col in df1.columns]
df1_processed = df1.drop(columns=existing_cols_to_drop)

print(f"Heart shape after dropping columns: {df1_processed.shape}")

def add_heart_to_dict(subject_dict, df):
    """Adds 'heart' data to existing subject_dict."""
    grouped = df.groupby('subject_id')
    
    for subject_id, group in grouped:
        rows_as_lists = group.values.tolist()
        
        if subject_id in subject_dict:
            subject_dict[subject_id]["heart"] = rows_as_lists
        else:
            subject_dict[subject_id] = {
                "heart": rows_as_lists
            }
    
    return subject_dict

# Add heart data to the dictionary
microbiology_dict = add_heart_to_dict(microbiology_dict, df1_processed)

# ============ SUMMARY ============
print(f"\nTotal unique subjects: {len(microbiology_dict)}")

subjects_with_both = sum(1 for sid, data in microbiology_dict.items() 
                         if "microbiology" in data and "heart" in data)
subjects_only_micro = sum(1 for sid, data in microbiology_dict.items() 
                          if "microbiology" in data and "heart" not in data)
subjects_only_heart = sum(1 for sid, data in microbiology_dict.items() 
                          if "heart" in data and "microbiology" not in data)

print(f"Subjects with both: {subjects_with_both}")
print(f"Subjects with only microbiology: {subjects_only_micro}")
print(f"Subjects with only heart: {subjects_only_heart}")

# # Example usage (commented):
# first_subject_id = list(microbiology_dict.keys())[0]
# print(f"\nExample - Subject ID: {first_subject_id}")
# print(f"Keys: {list(microbiology_dict[first_subject_id].keys())}")
# if "microbiology" in microbiology_dict[first_subject_id]:
#     print(f"Microbiology records: {len(microbiology_dict[first_subject_id]['microbiology'])}")
# if "heart" in microbiology_dict[first_subject_id]:
#     print(f"Heart records: {len(microbiology_dict[first_subject_id]['heart'])}")

# Save to JSON
with open('combined_dict.json', 'w') as f:
    json_dict = {str(k): v for k, v in microbiology_dict.items()}
    json.dump(json_dict, f, indent=2, default=str)
print("\nSaved to 'combined_dict.json'")
# Out:
# Original microbiology shape: (15587, 14)
# Original heart shape: (4864, 25)
# After removing QC_FAIL: (14808, 14)
# Unique subjects in microbiology: 2572
# Heart shape after dropping columns: (4864, 22)
#
# Total unique subjects: 4679
# Subjects with both: 2285
# Subjects with only microbiology: 287
# Subjects with only heart: 2107
#
# Saved to 'combined_dict.json'
