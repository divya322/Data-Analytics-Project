# %% [markdown]
# # Data understanding and preparation - Laboratory Tests
#
# The aim of this part is to extract some important features from the table `Laboratory_events`, in order to build insights for the patient profile.
# This notebook is divided in two parts:
# <ul>
#     <li><b>Data understanding</b></li>
#     <li><b>Data Preparation</b></li>
# </ul>
#
# Before diving into the further steps, ensure to have installed the data analitycs libraries:

# %%
# %conda install pandas seaborn scipy
# Out:
# 2 channel Terms of Service accepted
# Channels:
#  - defaults
# Platform: linux-64
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#     current version: 25.9.1
#     latest version: 25.11.1
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# # All requested packages already installed.
#
#
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Data understanding

# %% [markdown]
# ### Load the dataset

# %% [markdown]
# read the `.csv` file we need for the **DU**.

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from pathlib import Path

notebook_dir = Path().resolve()
LAB_CODES_PATH = notebook_dir.parents[1]  / "1" / "Data" / "laboratory_events_codes_2.csv"
df = pd.read_csv(LAB_CODES_PATH)

# %% [markdown]
# ### Semantic understanding of features
# Printing general about the dataFrame `df`

# %%
df.shape
# Out:
# (978503, 14)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 978503 entries, 0 to 978502
# Data columns (total 14 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   hadm_id            978503 non-null  float64
#  1   charttime          978503 non-null  object
#  2   value              934025 non-null  object
#  3   valuenum           907317 non-null  float64
#  4   valueuom           884585 non-null  object
#  5   ref_range_lower    865544 non-null  float64
#  6   ref_range_upper    865544 non-null  float64
#  7   flag               343687 non-null  object
#  8   label              978503 non-null  object
#  9   fluid              978503 non-null  object
#  10  examination_group  978503 non-null  object
#  11  analysis_batch_id  978503 non-null  object
#  12  qc_flag            978503 non-null  object
#  13  ref_range          146215 non-null  object
# dtypes: float64(4), object(10)
# memory usage: 104.5+ MB

# %%
df.describe(include="all")
# Out:
#              hadm_id            charttime   value       valuenum valueuom  \
# count   9.785030e+05               978503  934025  907317.000000   884585
# unique           NaN                66403    4284            NaN       47
# top              NaN  2172-04-23 08:45:00     ___            NaN    mg/dL
# freq             NaN                   93   68645            NaN   229227
# mean    2.504395e+07                  NaN     NaN      67.332325      NaN
# std     2.868159e+06                  NaN     NaN    2175.589189      NaN
# min     2.000446e+07                  NaN     NaN    -743.000000      NaN
# 25%     2.261232e+07                  NaN     NaN       4.300000      NaN
# 50%     2.510567e+07                  NaN     NaN      17.000000      NaN
# 75%     2.749772e+07                  NaN     NaN      60.200000      NaN
# max     2.999967e+07                  NaN     NaN  886449.000000      NaN
#
#         ref_range_lower  ref_range_upper      flag    label   fluid  \
# count     865544.000000    865544.000000    343687   978503  978503
# unique              NaN              NaN         1      502       9
# top                 NaN              NaN  abnormal  Glucose   Blood
# freq                NaN              NaN    343687    39744  918188
# mean          31.724619        55.794861       NaN      NaN     NaN
# std           44.840840       400.515033       NaN      NaN     NaN
# min            0.000000         0.000000       NaN      NaN     NaN
# 25%            3.300000         5.400000       NaN      NaN     NaN
# 50%           10.400000        20.000000       NaN      NaN     NaN
# 75%           36.000000        52.000000       NaN      NaN     NaN
# max         2200.000000    100000.000000       NaN      NaN     NaN
#
#                  examination_group analysis_batch_id qc_flag  \
# count                       978503            978503  978503
# unique                         202            227052       3
# top     Complete Blood Count (CBC)   BATCH_217602_T1      OK
# freq                        286407                39  880809
# mean                           NaN               NaN     NaN
# std                            NaN               NaN     NaN
# min                            NaN               NaN     NaN
# 25%                            NaN               NaN     NaN
# 50%                            NaN               NaN     NaN
# 75%                            NaN               NaN     NaN
# max                            NaN               NaN     NaN
#
#                   ref_range
# count                146215
# unique                    3
# top     Normal range: 10-20
# freq                  49098
# mean                    NaN
# std                     NaN
# min                     NaN
# 25%                     NaN
# 50%                     NaN
# 75%                     NaN
# max                     NaN

# %% [markdown]
# ## Data Preparation

# %%
string_cols = [
    "label", "fluid", "examination_group", "analysis_batch_id" "qc_flag",
]

# %%
for col in string_cols:
    if col in df.columns:
        print(f"\n---- Column: {col} ----")
        print("Sample unique values BEFORE cleaning:")
        print(df[col].dropna().unique()[:10])  # show first 10
# Out:
# ---- Column: label ----
# Sample unique values BEFORE cleaning:
# ['Creatine Kinase (CK)' 'Creatine Kinase, MB Isoenzyme' 'Troponin T'
#  'INR(PT)' 'PT' 'PTT' '% Hemoglobin A1c' 'eAG' 'Anion Gap' 'Bicarbonate']
#
# ---- Column: fluid ----
# Sample unique values BEFORE cleaning:
# ['Blood' 'Urine' 'Other Body Fluid' 'Pleural' 'Ascites'
#  'Cerebrospinal Fluid' 'Stool' 'Joint Fluid' 'Bone Marrow']
#
# ---- Column: examination_group ----
# Sample unique values BEFORE cleaning:
# ['Cardiac Markers' 'Coagulation and Hemostasis' 'HbA1c'
#  'Renal Function Tests' 'BMP' 'Lipid Panel' 'Complete Blood Count (CBC)'
#  'Liver Function Tests' 'Amylase' 'Vitamin and Nutritional Studies']

# %%
for col in string_cols:
    if col in df.columns:
        # Convert to string
        col_series = df[col].astype('string')
        # Find rows with leading/trailing spaces
        bad_spaces = df[col_series.str.contains(r"^\s+|\s+$", na=False)]
        # Count only non-NaN rows
        non_na_total = col_series.notna().sum()
        print(f"\n{col}: Rows with leading/trailing spaces = {len(bad_spaces)} / {non_na_total} (non-empty rows)")
        # Fix by stripping spaces
        df[col] = col_series.str.strip()
# Out:
# label: Rows with leading/trailing spaces = 0 / 978503 (non-empty rows)
#
# fluid: Rows with leading/trailing spaces = 0 / 978503 (non-empty rows)
#
# examination_group: Rows with leading/trailing spaces = 0 / 978503 (non-empty rows)

# %%
# ---- 6. qc_flag: check unique values ----
expected_qc_flag = {'OK', 'WARN', 'FAIL'}
unexpected_qc_flag = df[
    (~df["qc_flag"].isin(expected_qc_flag)) & 
    df["qc_flag"].notna()
]
print(f"\nUnexpected quality check flag labels: {len(unexpected_qc_flag)}")
if len(unexpected_qc_flag) > 0:
    display(unexpected_qc_flag.head())
# Out:
# Unexpected quality check flag labels: 0

# %%
#Chartime transformation 
df['charttime'] = pd.to_datetime(df['charttime'], errors='coerce')

# %%
df['hadm_id'] = df['hadm_id'].astype('int64')

# %%
df['value'] = df['value'].replace(['-', '--', '', ' '], np.nan)
df['value'] = (
    df['value']
    .str.replace('<', '', regex=False)
    .str.replace('>', '', regex=False)
)
df['value'] = pd.to_numeric(df['value'], errors='coerce')
df['value'] = df['value'].astype('float64')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 978503 entries, 0 to 978502
# Data columns (total 14 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   hadm_id            978503 non-null  int64
#  1   charttime          978503 non-null  datetime64[ns]
#  2   value              839422 non-null  float64
#  3   valuenum           907317 non-null  float64
#  4   valueuom           884585 non-null  object
#  5   ref_range_lower    865544 non-null  float64
#  6   ref_range_upper    865544 non-null  float64
#  7   flag               343687 non-null  object
#  8   label              978503 non-null  string
#  9   fluid              978503 non-null  string
#  10  examination_group  978503 non-null  string
#  11  analysis_batch_id  978503 non-null  object
#  12  qc_flag            978503 non-null  object
#  13  ref_range          146215 non-null  object
# dtypes: datetime64[ns](1), float64(4), int64(1), object(5), string(3)
# memory usage: 104.5+ MB

# %% [markdown]
# ### Data cleaning

# %% [markdown]
# #### Handle duplicate records

# %%
print(f"Before: {df.shape}")
df = df.drop_duplicates()
print(f"After: {df.shape}")
# Out:
# Before: (978503, 14)
# After: (978501, 14)

# %% [markdown]
# ####  Missing values
# We estimate the percentage of *missing values* contained in each column.

# %%
df.isna().mean().sort_values(ascending=False)
# Out:
# ref_range            0.850572
# flag                 0.648762
# value                0.142135
# ref_range_upper      0.115439
# ref_range_lower      0.115439
# valueuom             0.095979
# valuenum             0.072748
# charttime            0.000000
# hadm_id              0.000000
# label                0.000000
# fluid                0.000000
# examination_group    0.000000
# analysis_batch_id    0.000000
# qc_flag              0.000000
# dtype: float64

# %% [markdown]
# We can create a bar chart that reports the number of missing values in each variable

# %%
# Bar chart dei missing values per colonna (frequenza e percentuale)
missing_counts = df.isnull().sum()
total = len(df)
missing_counts = missing_counts.sort_values(ascending=False)
fig, ax = plt.subplots(figsize=(12, 6))
bars = ax.bar(missing_counts.index, missing_counts.values, color='tab:blue', alpha=0.8)
ax.set_title("Missing values relative frequency")
ax.set_xlabel("Attributes")
ax.set_ylabel("Missing values count")
ax.set_xticklabels(missing_counts.index, rotation=45, ha='right')
for bar, count in zip(bars, missing_counts.values):
    pct = count / total * 100
    ax.annotate(f"{count}\n{pct:.1f}%",
                xy=(bar.get_x() + bar.get_width() / 2, bar.get_height()),
                xytext=(0, 4), textcoords="offset points",
                ha='center', va='bottom', fontsize=9)

plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_91923/4090193844.py:10: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(missing_counts.index, rotation=45, ha='right')

# %% [markdown]
# From this bar chart we can now see that the `flag` and `ref_range` attributes have a lot of missing values.
# Let's have a look at them.

# %% [markdown]
# `flag` transformation

# %%
df['flag'].value_counts()
# Out:
# flag
# abnormal    343687
# Name: count, dtype: int64

# %% [markdown]
# We can replace the `abnormal` with a 1, and the rest of the fields we put a 0 which indicates that the test is not abnormal.

# %%
df['flag'] = df['flag'].str.strip().str.lower()
df['flag'] = df['flag'].apply(lambda x: 1 if x == 'abnormal' else 0)
df['flag'].value_counts()
# Out:
# flag
# 0    634814
# 1    343687
# Name: count, dtype: int64

# %% [markdown]
# `ref_range` elimination

# %% [markdown]
# This variable has ~80% of values missing. <br>
# Moreover, we can observe that there isn't coerence between the values of `ref_range_lower`, `ref_range_upper` and `ref_range`. <br>
# Therefore, we can drop the column `ref_range` because it has already a big percentage of missing values.

# %%
ref_range_not_null = df[df['ref_range'].notna()][['ref_range', 'ref_range_lower', 'ref_range_upper']]
ref_range_not_null.head()
# Out:
#                ref_range  ref_range_lower  ref_range_upper
# 6   Normal range: 70-110              4.8              5.9
# 10   Normal range: 10-20              8.4             10.3
# 21     Normal range: 3-5              2.7              4.5
# 29     Normal range: 3-5             27.0             32.0
# 32  Normal range: 70-110            150.0            440.0

# %%
df.drop(columns=['ref_range'], inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 978501 entries, 0 to 978502
# Data columns (total 13 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   hadm_id            978501 non-null  int64
#  1   charttime          978501 non-null  datetime64[ns]
#  2   value              839422 non-null  float64
#  3   valuenum           907317 non-null  float64
#  4   valueuom           884585 non-null  object
#  5   ref_range_lower    865544 non-null  float64
#  6   ref_range_upper    865544 non-null  float64
#  7   flag               978501 non-null  int64
#  8   label              978501 non-null  string
#  9   fluid              978501 non-null  string
#  10  examination_group  978501 non-null  string
#  11  analysis_batch_id  978501 non-null  object
#  12  qc_flag            978501 non-null  object
# dtypes: datetime64[ns](1), float64(4), int64(2), object(3), string(3)
# memory usage: 104.5+ MB

# %% [markdown]
# `valuenum` and `valueuom` correction

# %% [markdown]
# Let's assume we have tests that can provide useful information (insights). To infer metrics, we need to discard tests that don't have a valid `valuenum` numerical value.

# %%
df = df.dropna(subset=['valuenum'])
df['valuenum'].isna().mean()
# Out:
# np.float64(0.0)

# %% [markdown]
# The type of test is recognized only by the label, the type of fluid analyzed and the unit of measurement. <br>
# The `valueuom` can be inferred with the type of the test (`label` and `fluid`)

# %%
import numpy as np
import pandas as pd

# 0) Pre-cleaning 
df['valueuom'] = df['valueuom'].astype(object)  
df['valueuom'] = df['valueuom'].str.strip().replace({'': np.nan})  

# --- 1) (label, fluid): mode per unique tests
modes_lf = (
    df.dropna(subset=['valueuom'])  
      .groupby(['label', 'fluid'])['valueuom']
      .agg(lambda s: s.mode().iat[0] if not s.mode().empty else np.nan)
      .reset_index()
      .rename(columns={'valueuom': 'mode_uom'})
)

map_lf = { (r['label'], r['fluid']): r['mode_uom'] for _, r in modes_lf.iterrows() }

def fill_uom_by_label_fluid(row):
    if pd.notna(row['valueuom']):
        return row['valueuom']
    key = (row['label'], row['fluid'])
    return map_lf.get(key, np.nan)

df['valueuom'] = df.apply(fill_uom_by_label_fluid, axis=1)

# --- 2) fallback: label only mode (for the rest of missing)
modes_label = (
    df.dropna(subset=['valueuom']) 
      .groupby('label')['valueuom']
      .agg(lambda s: s.mode().iat[0] if not s.mode().empty else np.nan)
      .reset_index()
      .rename(columns={'valueuom': 'mode_label'})
)

map_label = dict(zip(modes_label['label'], modes_label['mode_label']))

df['valueuom'] = df.apply(
    lambda r: r['valueuom'] if pd.notna(r['valueuom']) else map_label.get(r['label'], np.nan),
    axis=1
)

# 3) mark remaining as 'Unknown'
df['valueuom'] = df['valueuom'].fillna('Unknown')

# Check
print('Percent missing after fill:', (df['valueuom']=='Unknown').mean())

# Remove mode columns if they exist
cols_to_drop = [c for c in ['mode_uom_x', 'mode_uom_y'] if c in df.columns]
if cols_to_drop:
    df.drop(columns=cols_to_drop, inplace=True)
# Out:
# Percent missing after fill: 0.02767830868373457

# %% [markdown]
# We can discard these unique tests.

# %%
lab_stats = df.groupby('label').agg({
    'valueuom': lambda x: (x == 'Unknown').mean() * 100, 
    'valuenum': lambda x: x.notna().mean() * 100
})

lab_stats.columns = ['pct_unknown_uom', 'pct_present_valuenum']

# 2. Define the label
mask_bad_labels = (lab_stats['pct_unknown_uom'] == 100) & (lab_stats['pct_present_valuenum'] > 0)
bad_labels = lab_stats[mask_bad_labels].index

print(f"Elimination of {len(bad_labels)} test type that have no unit measure.")

indices_to_drop = df[df['label'].isin(bad_labels)].index
df.drop(indices_to_drop, axis=0, inplace=True)

print(f"{len(indices_to_drop)} records are discarded.")
# Out:
# Elimination of 42 test type that have no unit measure.
# 25113 records are discarded.

# %% [markdown]
# `ref_range_upper` and `ref_range_lower` correction

# %% [markdown]
# To start, we handle the missing values. <br>
# We can check the percentage of missing values on the reference ranges associated with an laboratory exam type (denoted by the `label`, `fluid` and `valueuom`).

# %%
missing_pct = df.groupby(["label", "valueuom", "fluid"])[["ref_range_lower", "ref_range_upper", "valuenum", "valueuom"]].apply(lambda g: g.isna().mean())
missing_pct[(missing_pct['ref_range_lower'] > 0) & (missing_pct['ref_range_upper'] > 0)].sort_values(by=['ref_range_lower', 'ref_range_upper'], ascending=False)
# Out:
#                                             ref_range_lower  ref_range_upper  \
# label                     valueuom fluid
# 24 hr Calcium             mg/24hr  Urine           1.000000         1.000000
# 24 hr Creatinine          mg/24hr  Urine           1.000000         1.000000
# 24 hr Protein             mg/24hr  Urine           1.000000         1.000000
# Absolute Lymphocyte Count #/uL     Blood           1.000000         1.000000
# Albumin, Ascites          g/dL     Ascites         1.000000         1.000000
# ...                                                     ...              ...
# Glucose                   mg/dL    Urine           0.879668         0.879668
# Immature Granulocytes     %        Blood           0.581330         0.581330
# Prostate Specific Antigen ng/mL    Blood           0.037037         0.037037
# pH                        units    Urine           0.006248         0.006248
# C-Reactive Protein        mg/L     Blood           0.003731         0.003731
#
#                                             valuenum  valueuom
# label                     valueuom fluid
# 24 hr Calcium             mg/24hr  Urine         0.0       0.0
# 24 hr Creatinine          mg/24hr  Urine         0.0       0.0
# 24 hr Protein             mg/24hr  Urine         0.0       0.0
# Absolute Lymphocyte Count #/uL     Blood         0.0       0.0
# Albumin, Ascites          g/dL     Ascites       0.0       0.0
# ...                                              ...       ...
# Glucose                   mg/dL    Urine         0.0       0.0
# Immature Granulocytes     %        Blood         0.0       0.0
# Prostate Specific Antigen ng/mL    Blood         0.0       0.0
# pH                        units    Urine         0.0       0.0
# C-Reactive Protein        mg/L     Blood         0.0       0.0
#
# [98 rows x 4 columns]

# %%
print(f"Missing values percentage in reference ranges : \n {df['ref_range_lower'].isna().mean()}\n {df['ref_range_upper'].isna().mean()}")

mode_df = df.groupby(['label', 'fluid', 'valueuom']).agg({
    'ref_range_lower': lambda x: x.mode()[0] if len(x.mode()) > 0 else None,
    'ref_range_upper': lambda x: x.mode()[0] if len(x.mode()) > 0 else None
})

def fill_ref_ranges(row):
    key = (row['label'], row['fluid'], row['valueuom'])
    if pd.isna(row['ref_range_lower']) and key in mode_df.index:
        row['ref_range_lower'] = mode_df.loc[key, 'ref_range_lower']
    if pd.isna(row['ref_range_upper']) and key in mode_df.index:
        row['ref_range_upper'] = mode_df.loc[key, 'ref_range_upper']
    return row

df = df.apply(fill_ref_ranges, axis=1)
print(f"Missing values percentage in reference ranges after mode imputation: \n {df['ref_range_lower'].isna().mean()}\n {df['ref_range_upper'].isna().mean()}")
# Out:
# Missing values percentage in reference ranges :
#  0.05455427542835897
#  0.05455427542835897
# Missing values percentage in reference ranges after mode imputation:
#  0.027866570543774456
#  0.027866570543774456

# %% [markdown]
# After the value inference by the mode of the (`ref_range_lower`,`ref_range_upper`) for each group identified by the unique test key (`label`, `fluid`, `valueuom`), we delete any record that have missing ref range values.

# %%
# For each unique test, count the number of rows and how many have missing ref_range_lower or ref_range_upper
missing_stats = (
    df.groupby(['label', 'fluid', 'valueuom'])[['ref_range_lower', 'ref_range_upper']]
      .apply(lambda g: pd.Series({
          'total': len(g),
          'missing': g[['ref_range_lower', 'ref_range_upper']].isna().any(axis=1).sum()
      }))
      .assign(missing_pct=lambda d: d['missing'] / d['total'] * 100)
      .sort_values('missing_pct', ascending=False)
)

# remove unique tests with at least one missing
mask = ((missing_stats['missing'] > 0) & (missing_stats['missing'] == missing_stats['total']))
bad_combinations = missing_stats[mask].index
df = df.set_index(['label', 'fluid', 'valueuom'])
df = df.drop(index=bad_combinations, errors='ignore')
df = df.reset_index()

print("Missing percentage after removal:")
print(df['ref_range_lower'].isna().mean())
print(df['ref_range_upper'].isna().mean())
# Out:
# Missing percentage after removal:
# 0.0
# 0.0

# %% [markdown]
# Now, we can conclude that we have no missing values in our dataframe.

# %%
df.isna().mean().sort_values(ascending=False)
# Out:
# value                0.078669
# fluid                0.000000
# valueuom             0.000000
# hadm_id              0.000000
# label                0.000000
# charttime            0.000000
# valuenum             0.000000
# ref_range_lower      0.000000
# ref_range_upper      0.000000
# flag                 0.000000
# examination_group    0.000000
# analysis_batch_id    0.000000
# qc_flag              0.000000
# dtype: float64

# %% [markdown]
# #### Detecting redundant variables

# %%
df[['value', 'valuenum']].corr()
# Out:
#           value  valuenum
# value       1.0       1.0
# valuenum    1.0       1.0

# %% [markdown]
# We observe that `value` is completely redundant, so we remove it.

# %%
df = df.drop(columns=["value"])

# %% [markdown]
# ## Data quality

# %%
# Histogram per examination_group
tests_per_group = (
    df.groupby('examination_group')['label']
      .nunique()
      .sort_values(ascending=False)
      .reset_index(name='unique_test_count') 
)

plt.figure(figsize=(12, 6))

sns.barplot(
    data=tests_per_group, 
    x='examination_group', 
    y='unique_test_count', 
    palette='viridis',
    hue='examination_group', 
    legend=False
)

plt.title('Count of type tests per examination group', fontsize=14)
plt.xlabel('Examination group', fontsize=10)
plt.ylabel('Type tests count', fontsize=12)
plt.xticks(rotation=45, ha='right') 
plt.grid(axis='y', linestyle='--', alpha=0.7)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Normalization

# %% [markdown]
# The only numerical attributes that we have are: `ref_range_lower`, `ref_range_upper`, `valuenum`. <br>
# Before analysing their distributions we need to normalize them.

# %% [markdown]
# #### `valueuom` normalization

# %% [markdown]
# In this section we apply normalization (standardization) of `valueuom` w.r.t the unique tests.

# %%
# Identify unique tests (label, fluid) with multiple units of measurement (valueuom)
grouped = df.groupby(['label', 'fluid'])['valueuom']
multi = grouped.nunique()
multi = multi[multi > 1]

for label, fluid in multi.index:
    subset = df[(df['label'] == label) & (df['fluid'] == fluid)]
    print(f"Unique test: {label} - {fluid}")
    print(f"Number of units of measurement: {len(subset['valueuom'].unique())}")
    # for col in ['ref_range_lower', 'ref_range_upper']:
    #     vc = subset[col].value_counts()
    #     n_unique = vc.size
    #     print(f"  {col}: unique={n_unique}")
    print("-" * 60)
# Out:
# Unique test: D-Dimer - Blood
# Number of units of measurement: 2
# ------------------------------------------------------------
# Unique test: HIV 1 Viral Load - Blood
# Number of units of measurement: 2
# ------------------------------------------------------------
# Unique test: Heparin - Blood
# Number of units of measurement: 2
# ------------------------------------------------------------
# Unique test: MCHC - Blood
# Number of units of measurement: 2
# ------------------------------------------------------------
# Unique test: Protein/Creatinine Ratio - Urine
# Number of units of measurement: 2
# ------------------------------------------------------------

# %%
#principal unit measure -> mode (the more frequent unit of measure for each label)
main_unit = (
    df.groupby(['label', 'fluid'])['valueuom']
      .agg(lambda x: x.mode()[0])
)

for label in multi.index:
    print (f"{label} : {main_unit[label]}")
# Out:
# ('D-Dimer', 'Blood') : ng/mL
# ('HIV 1 Viral Load', 'Blood') : log10 cop/mL
# ('Heparin', 'Blood') : IU/mL
# ('MCHC', 'Blood') : %
# ('Protein/Creatinine Ratio', 'Urine') : Ratio

# %%
# Identify labels with multiple units of measurement and plot their distributions
grouped = df.groupby(['label', 'fluid'])['valueuom']
multi = grouped.nunique()
multi = multi[multi > 1]

for label, fluid in multi.index:
    subset = df[(df['label'] == label) & (df['fluid'] == fluid)]
    fig, ax = plt.subplots(figsize=(10, 5))
    sns.kdeplot(data=subset, x='valuenum', hue='valueuom', ax=ax)
    
    # Add reference range lines for each unit of measurement
    for uom in subset['valueuom'].unique():
        uom_data = subset[subset['valueuom'] == uom]
        ref_lower = uom_data['ref_range_lower'].iloc[0]
        ref_upper = uom_data['ref_range_upper'].iloc[0]
        ax.axvline(ref_lower, linestyle='--', alpha=0.5, label=f'{uom} ref_lower')
        ax.axvline(ref_upper, linestyle='--', alpha=0.5, label=f'{uom} ref_upper')
    
    ax.set_title(f'{label} ({fluid})')
    ax.legend()
    plt.tight_layout()
    plt.show()
# Out:
# /tmp/ipykernel_91923/2326021144.py:9: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(data=subset, x='valuenum', hue='valueuom', ax=ax)

# %% [markdown]
# In many of the graphs above, the different units of measurement for the unique tests match, so only the mode conversion occurs in the unit of measurement for that test. <br>
# In the only case where we have two units of measurement with different ranges, we perform a standardization.
#
# `Absolute Lymphocyte Count`: The `#/uL` means the amount of cells that are in one microliter. Meanwhile `K/uL` means thousands of cells in a microliter. <br>
# We normalize only the `valuenum` in the unit of measurement represented by the mode (`K/uL`);
#
# `D-dimer`: `ng/mL` and `ng/mL FEU` (Fibrinogen Equivalent Units) are the same unit, so we substitute for the mode of the unit;
#
# `HIV 1 Viral Load`: the standard unit of measure is copies/mL. We don't need to normalize the data in this case because they are representing the same unit of measure;
#
# `Heparin`: Both IU/mL and U/mL refer to the anticoagulant activity of heparin per milliliter of solution. <br>
# "International Unit" (IU) is the official term established by the World Health Organization (WHO) to standardize the measurement of biological activities, including heparin. <br>
# The abbreviation "U" is frequently used in clinical settings for simplicity and does not represent a different unit;
#
# `MCHC`: `g/dL` is the standard unit for expressing the average concentration of hemoglobin in a volume of red blood cells. <br>
# Meanwhile `%` is a percentage value of the hemoglobin concentration within the red blood cells and is numerically equivalent to the g/dL value. <br>
# In conclusion, they are both equivalent. <br>
# We take g/dL given that it's the mode and the standard unit of measure.
# In this particular setting, we need to normalize the records put in `%` measure.
# The normalization applied is in the range of 32% and 36% (see <a href="https://en.wikipedia.org/wiki/Mean_corpuscular_hemoglobin_concentration" > Wiki</a>);
#
# `Protein/Creatinine ratio`: The different `valueuom` (that is, `Ratio` and `mg/mg`) indicate the same measure, that is the protein/creatinine ratio in urine used to evaluate kidney function. We can substitute the `valueuom` of `mg/mg` into `Ratio` (the mode of this measure, in this particular label).

# %%
conversions = {
    'Absolute Lymphocyte Count': ('#/uL', 'K/uL', 1/1000),
    'D-Dimer': ('ng/mL FEU', 'ng/mL', 1),
    'HIV 1 Viral Load': ('log10 cop/mL', 'log10 copies/mL', 1),
    'Heparin': ('U/mL', 'IU/mL', 1),
    'Protein/Creatinine Ratio': ('mg/mg', 'Ratio', 1)
}

def convert_unit(df, label, old_uom, new_uom, factor=1.0):
    mask = (df["label"] == label) & (df["valueuom"] == old_uom)
    if mask.any():
        if factor != 1.0:
            df.loc[mask, "valuenum"] = df.loc[mask, "valuenum"] * factor

        df.loc[mask, "valueuom"] = new_uom
        print(f"[OK] {label}: converted '{old_uom}' -> '{new_uom}' (factor: {factor})")
    else:
        print(f"[SKIP] {label}: unit '{old_uom}' not found.")

# %%
def normalize_by_ref_range(df, label, from_uom, to_uom):
    """
    Run conversion based on reference ranges (MCHC -> from g/dL to %).
    """
    mask_from = (df["label"] == label) & (df["valueuom"] == from_uom)
    mask_to = (df["label"] == label) & (df["valueuom"] == to_uom)

    if not mask_from.any() or not mask_to.any():
        print(
            f"[SKIP] {label}: Missing data for conversion from '{from_uom}' to '{to_uom}'"
        )
        return

    try:
        ref_lower_target = df.loc[mask_to, "ref_range_lower"].iloc[0]
        ref_upper_target = df.loc[mask_to, "ref_range_upper"].iloc[0]

        ref_lower_source = df.loc[mask_from, "ref_range_lower"].iloc[0]
        ref_upper_source = df.loc[mask_from, "ref_range_upper"].iloc[0]

        # Scale factor (slope)
        # Formula: new_val = new_min + (val - old_min) * (new_range / old_range)
        scale_factor = (ref_upper_target - ref_lower_target) / (
            ref_upper_source - ref_lower_source
        )

        # Apply conversion
        df.loc[mask_from, "valuenum"] = (
            ref_lower_target
            + (df.loc[mask_from, "valuenum"] - ref_lower_source) * scale_factor
        )

        # Update unit measure and reference ranges
        df.loc[mask_from, "valueuom"] = to_uom
        df.loc[mask_from, "ref_range_lower"] = ref_lower_target
        df.loc[mask_from, "ref_range_upper"] = ref_upper_target

    except IndexError:
        print(f"[ERROR] {label}: Could not retrieve unique reference ranges.")

# %%
#Apply conversions
for label, params in conversions.items():
    old_uom, new_uom, factor = params
    convert_unit(df, label, old_uom, new_uom, factor)
    
normalize_by_ref_range(df, 'MCHC', from_uom='g/dL', to_uom='%')
# Out:
# [SKIP] Absolute Lymphocyte Count: unit '#/uL' not found.
# [OK] D-Dimer: converted 'ng/mL FEU' -> 'ng/mL' (factor: 1)
# [OK] HIV 1 Viral Load: converted 'log10 cop/mL' -> 'log10 copies/mL' (factor: 1)
# [OK] Heparin: converted 'U/mL' -> 'IU/mL' (factor: 1)
# [OK] Protein/Creatinine Ratio: converted 'mg/mg' -> 'Ratio' (factor: 1)

# %%
grouped_check = df.groupby(['label', 'fluid'])['valueuom'].nunique()
duplicates = grouped_check[grouped_check > 1]

if duplicates.empty:
    print("All units are now standardized per label/fluid.")
else:
    print(f"Still found mixed units for: {duplicates.index.tolist()}")
# Out:
# All units are now standardized per label/fluid.

# %% [markdown]
# #### Normalization of `ref_range_lower` and `ref_range_upper`

# %% [markdown]
# We did not normalize the reference ranges so as not to lose the clinical specificity related to the age of the patients. <br>
# Below are some histograms to show the frequency distribution of the different ranges by type of test and by type of examination group.

# %%
# Verifica unique test che presentano più di una coppia (ref_range_lower, ref_range_upper)
range_counts = (
    df.groupby(['label', 'fluid', 'valueuom'])[['ref_range_lower', 'ref_range_upper']]
      .apply(lambda g: g.drop_duplicates().shape[0])
      .rename('n_distinct_ranges')
)

plt.figure(figsize=(10, 6))
ax = sns.histplot(range_counts, discrete=True, shrink=0.8)
plt.title('Reference Ranges Distribution per test type', fontsize=14)
plt.xlabel('Count of distinct reference ranges', fontsize=12)
plt.ylabel('Type tests count (Label + Fluid + UoM)', fontsize=12)
plt.xticks(range(1, range_counts.max() + 1)) # Forza mostrare tutti i numeri interi sull'asse X
plt.grid(axis='y', linestyle='--', alpha=0.7)
for p in ax.patches:
    height = p.get_height()
    if height > 0:
        ax.text(p.get_x() + p.get_width() / 2., height + 0.5, int(height), ha="center")
plt.tight_layout()
plt.show()

# %%
# Test distribution by fluid type
tests_per_fluid = (
    df.groupby('fluid')
      .size()
      .rename('n_tests')
      .reset_index()
      .sort_values('n_tests', ascending=False)
)

# Percentage on total tests
total_tests = tests_per_fluid['n_tests'].sum()
tests_per_fluid['perc'] = tests_per_fluid['n_tests'] / total_tests

# Percentage column rounded for labels
tests_per_fluid['perc_label'] = (tests_per_fluid['perc'] * 100).round(1)

plt.figure(figsize=(10, 5))
ax = sns.barplot(
    data=tests_per_fluid,
    x='fluid',
    y='perc',
    palette='Blues_d'
)

# label above percentage bars
for p, perc in zip(ax.patches, tests_per_fluid['perc_label']):
    ax.text(
        x=p.get_x() + p.get_width() / 2,
        y=p.get_height(),
        s=f'{perc}%',
        ha='center',
        va='bottom',
        fontsize=9
    )

ax.set_title('Distribution of laboratory tests by fluid type', fontsize=14)
ax.set_xlabel('Fluid type', fontsize=12)
ax.set_ylabel('Percentage of tests', fontsize=12)
plt.xticks(rotation=45, ha='right')
plt.ylim(0, tests_per_fluid['perc'].max() * 1.15) 
plt.grid(axis='y', linestyle='--', alpha=0.4)
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_91923/1134927228.py:18: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(

# %% [markdown]
# Since almost all laboratory tests are performed on blood, while other fluids have a very small number of observations, focusing the analysis only on blood allows us to work with numerically consistent data and avoid weak conclusions about rarely tested fluids.

# %%
df_blood = df[df['fluid'] == 'Blood'].copy()

# %% [markdown]
# ### Outliers detection

# %%
#Build heatmap of abnormal ratio per unique test (label x fluid)
agg = (
    df
    .groupby((['label', 'fluid']))
    .agg(
        total_tests = ('valuenum', 'size'),
        abnormal_tests = ('flag', 'sum')
        )
    )

agg['abnormal_ratio'] = (agg['abnormal_tests'] / agg['total_tests']).round(3)
agg.sort_values(by='abnormal_ratio', ascending=False)
tmp = agg.reset_index()

print("righe in agg:", len(tmp))
print("coppie (label, fluid) uniche:", len(tmp[['label', 'fluid']].drop_duplicates()))

# pivot per la heatmap: righe = fluid, colonne = label
heat_pivot = agg.reset_index().pivot(index='fluid', columns='label', values='abnormal_ratio')


#heatmap abnormal ratio for every unique test (label x fluid)
plt.figure(figsize=(14, 5))
sns.heatmap(
    heat_pivot,
    annot=False,          
    cmap="Reds",
    cbar_kws={'label': 'Abnormal ratio'},
    vmax=0.5
)

plt.xticks(rotation=90, fontsize=6)
plt.yticks(fontsize=8)
plt.title("Abnormal test percentage by label × fluid", fontsize=12)
plt.xlabel("Test (label)")
plt.ylabel("Fluid")
plt.tight_layout()
plt.show()
# Out:
# righe in agg: 247
# coppie (label, fluid) uniche: 247

# %% [markdown]
# <b>Heatmap Interpretation</b>
# <ul>
#     <li>Column = test (label).</li>
#     <li>Row = fluid.</li>
#     <li>Each colored vertical bar = how often that test is abnormal on that fluid.</li>
#     <li>The darker the color, the higher the percentage of abnormal results in that group.</li>
# </ul>
#
# In Blood, some tests often have abnormal values ​​(very dark columns). <br>
# For other fluids, you have few tests but with very high ratios (e.g., very few tests, almost all abnormal).
#
# Another thing we can note is the large number of tests available for the fluid type "Blood." We can analyze the test distributions by fluid type to confirm this statement.

# %% [markdown]
# The outlier detection have to be performed only to `valuenum` numerical value, in order to find errors on tests. <br>
# Outliers should be displayed by the test `label` now, because before we implictly standardize the `fluid` into `Blood`.

# %%
def flag_outliers_iqr(g):
    q1 = g['valuenum'].quantile(0.25)
    q3 = g['valuenum'].quantile(0.75)
    iqr = q3 - q1
    lo = q1 - 1.5 * iqr
    hi = q3 + 1.5 * iqr
    return (g['valuenum'] < lo) | (g['valuenum'] > hi)

# %%
df_blood['is_outlier_iqr'] = (
    df_blood
    .groupby('label', group_keys=False)
    .apply(flag_outliers_iqr)
)
# Out:
# /tmp/ipykernel_91923/1177423822.py:4: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(flag_outliers_iqr)

# %%
# Define condition error for the outliers based on reference ranges and on flag/qc_flag
k = 5
cond_range = (
    (df_blood['valuenum'] < 0)
    |
    (
        df_blood['ref_range_lower'].notna()
        & 
        ((df_blood['valuenum'] > k * df_blood['ref_range_upper'])
           | (df_blood['valuenum'] < (1/k) * df_blood['ref_range_lower'])
        )
    )
)

cond_flag = (
    (df_blood['qc_flag'] != 'OK')     
)

# %% [markdown]
# for each test we calculate the percentage of measurements marked as suspicious errors.

# %%
df_blood['suspected_error'] = (
    df_blood['is_outlier_iqr'] &
    cond_range & 
    cond_flag  
)

mean_errors = df_blood.groupby('label')['suspected_error'].mean()
low  = mean_errors[mean_errors < 0.001]
mid  = mean_errors[(mean_errors >= 0.001) & (mean_errors <= 0.05)]
high = mean_errors[mean_errors > 0.05]
print (f"{len(low)} tests with low suspected errors.")
print (f"{len(mid)} tests with mid suspected errors.")
print (f"{len(high)} tests with high suspected errors.")
# Out:
# 150 tests with low suspected errors.
# 23 tests with mid suspected errors.
# 2 tests with high suspected errors.

# %% [markdown]
#  We decide for the moment to remove only the records with suspicious values from the all records.

# %%
for lab in high.index:
    subset = df_blood[df_blood['label'] == lab].copy()

    # categorical column (error flag)
    subset['error_flag'] = subset['suspected_error'].map(
        {False: 'Normal', True: 'Suspected error'}
    )

    plt.figure(figsize=(10, 4))

    # Histogram
    plt.subplot(1, 2, 1)
    sns.histplot(
        data=subset,
        x='valuenum',
        hue='error_flag',
        multiple='layer',
        palette={'Normal': 'steelblue', 'Suspected error': 'red'}, 
        kde=False, 
    )
    plt.title(f'{lab} - Histogram (Blood)')
    plt.xlabel('Value')
    plt.ylabel('Count')

    # Boxplot
    plt.subplot(1, 2, 2)
    sns.boxplot(
        data=subset,
        x='valuenum',
        hue='error_flag',
        y='error_flag',
        orient='h',
        palette={'Normal': 'steelblue', 'Suspected error': 'red'},
        legend=False
    )
    plt.title(f'{lab} - Boxplot (Blood)')
    plt.xlabel('Value')
    plt.ylabel('')

    plt.tight_layout()
    plt.show()

# %%
print("Total rows in df_blood:", len(df_blood))
df_blood_clean = df_blood[~df_blood['suspected_error']].copy()
print("Total rows after clean:", len(df_blood_clean))
# Out:
# Total rows in df_blood: 847077
# Total rows after clean: 846463

# %% [markdown]
# We don't loose so much records

# %% [markdown]
# ### Feature projection

# %% [markdown]
# At this point, we can extract interesting characteristics from the test groups involving a single hospital admission.
#
# These characteristics will then provide important information when building the patient profile.
#
# <ul> <b> Global features (for patient) </b>
# <li> total_tests: Total number of laboratory tests performed during the hospitalization (count of all rows in the Laboratory Events table for hadm_id). Measures the overall intensity of laboratory monitoring; hospitalizations with many tests suggest greater clinical complexity or severity of the condition.</li>
#
# <li> n_invalid: Number of laboratory tests marked as abnormal (flag = 1) for each hospitalization. Quantifies how many times during the hospitalization, laboratory parameters deviated from the reference range, indicating clinical instability.</li>
#
# <li> tests_days_span: Difference in days between the first and last laboratory chart times recorded for the hospitalization. Approximates the duration of the laboratory monitoring window; longer hospitalizations or those with extended follow-up of tests may indicate more complex conditions.</li>
#
# <li>perc_invalid: Ratio between n_invalid and total_tests for each hospitalization. Normalizes the number of abnormal tests relative to the total number of tests, providing a measure of abnormality density independent of test volume.</li>
# </ul>
#
# <ul><b>Potassium features</b>
# <li>k_min and k_max: Minimum and maximum potassium values ​​recorded during hospitalization. Extreme potassium levels (hypo- or hyperkalemia) are strongly associated with arrhythmia risk and mortality in cardiac patients; these features summarize the degree of exposure to potentially dangerous values.</li>
#
# <li>k_n:
# Number of potassium measurements per hospitalization. Indicates how closely potassium is monitored, potentially related to clinical perception of electrolyte risk.</li>
#
# <li>k_abnormal_ratio: Ratio of the number of potassium measurements outside of range to the total number of potassium measurements. Measures the patient's electrolyte stability with respect to potassium; high values ​​indicate difficulty controlling and increased arrhythmic risk.</li>
# </ul>
#
# <ul> <b>Sodium, chloride, and Na/Cl ratio</b>
# (Computed on rows with label = "Sodium" or label = "Chloride".)
#
# <li>na_min, na_max
# Minimum and maximum serum sodium during the admission. hyponatremia is a well-known marker of poor prognosis in heart failure, and deviations in either direction are linked to worse outcomes.​</li>
#
# <li>cl_min, cl_max
# Minimum and maximum serum chloride during the admission. low chloride has been associated with increased mortality in heart failure and adds prognostic information beyond sodium alone.​</li>
#
# <li>na_n, cl_n and na_abnormal_ratio, cl_abnormal_ratio
# Count of sodium/chloride measurements and proportion of out-of-range values. describe how frequently and how severely the patient leaves the physiological range for these key electrolytes, reflecting volume status and decompensation.</li>
#
# <li>na_cl_ratio
# Sodium-to-chloride ratio, typically computed from mean (or median) sodium and chloride per admission. recent studies show that the Na/Cl ratio is an independent predictor of in-hospital and long-term mortality in acute heart failure and ICU patients, making it a compact marker of electrolyte imbalance.​</li>
#
# </ul>
#
#
# <ul> <b>Creatinine and glucose features </b> (Computed on rows with label = `Creatinine` or label = `Glucose`.)
#
# <li>creat_max
# Maximum creatinine value during the admission. captures the worst degree of renal impairment; worsening kidney function is tightly linked to adverse cardiovascular outcomes and is central in cardio‑renal interactions.​</li>
#
# <li>creat_n, creat_abnormal_ratio:
# Number of creatinine measurements and fraction of abnormal values. indicate how much renal function is monitored and how frequently it is outside the reference range, summarizing the burden of renal dysfunction.​</li>
#
# <li>glu_max:
# Maximum glucose value during the admission. acute hyperglycemia, even in non‑diabetic patients, is associated with increased cardiovascular event rates and worse outcomes in acute settings.​</li>
#
# <li>glu_n, glu_abnormal_ratio:
# Number of glucose measurements and proportion of out-of-range values. reflect both the intensity of glucose monitoring and the difficulty in maintaining glucose within target, i.e., the degree of metabolic dysregulation.</li>
#
# <li>glu_var: glycemic variability has been identified as an independent risk factor for vascular complications and major cardiovascular events, beyond mean glucose levels.</li>

# %%
df_blood_clean['label'].value_counts().head()
# Out:
# label
# Potassium     37837
# Glucose       36876
# Sodium        36712
# Chloride      36611
# Creatinine    35858
# Name: count, dtype: int64

# %%
# global features for admission
hadm_tests = (
    df_blood_clean
    .groupby('hadm_id')
    .agg(
        total_tests=('valuenum', 'size'),
        n_invalid=('flag', 'sum'),
        tests_days_span=('charttime', lambda x: (x.max() - x.min()).days)
    )
    .assign(
        perc_invalid=lambda x: x['n_invalid'] / x['total_tests']
    )
    .round({
        'perc_invalid': 3  
    })
)


# utility function for extracting min, max e anomal ratio for one single test
def lab_features_for(label_name, prefix):
    df_lab = df_blood_clean[df_blood_clean['label'] == label_name]
    return (
        df_lab
        .groupby('hadm_id')
        .agg(**{
            f'{prefix}_min': ('valuenum', 'min'),
            f'{prefix}_max': ('valuenum', 'max'),
            f'{prefix}_n':   ('valuenum', 'size'),
            f'{prefix}_n_abnormal': ('flag', 'sum'),
        })
        .assign(**{
            f'{prefix}_abnormal_ratio': lambda x: x[f'{prefix}_n_abnormal'] / x[f'{prefix}_n']
        })
        .round({
            f'{prefix}_abnormal_ratio': 3,
            f'{prefix}_min': 2,
            f'{prefix}_max': 2
        })
    )


# Potassium
k_feats = lab_features_for('Potassium', 'k')


# Sodium
na_feats = lab_features_for('Sodium', 'na')


# Chloride
cl_feats = lab_features_for('Chloride', 'cl')


# Creatinine
creat_feats = lab_features_for('Creatinine', 'creat')


# Glucose
glu_feats = lab_features_for('Glucose', 'glu').assign(
    glu_var=lambda x: df_blood_clean[df_blood_clean['label'] == 'Glucose']
                        .groupby('hadm_id')['valuenum'].std().round(2)
)


# ratio Na/Cl
na_cl_ratio = (
    df_blood_clean[df_blood_clean['label'].isin(['Sodium', 'Chloride'])]
    .pivot_table(
        index='hadm_id',
        columns='label',
        values='valuenum',
        aggfunc='mean'
    )
    .rename_axis(columns=None)
    .assign(
        na_cl_ratio=lambda x: (x['Sodium'] / x['Chloride']).round(2)
    )[['na_cl_ratio']]
)

# %% [markdown]
# ## Outliers detection

# %%
from functools import reduce

dfs = [
    hadm_tests,
    k_feats,
    na_feats,
    cl_feats,
    creat_feats,
    glu_feats,
    na_cl_ratio,
]

hadm_tests_full = reduce(
    lambda left, right: left.merge(right, on='hadm_id', how='left'),
    dfs
).reset_index()

# %% [markdown]
# ### Anomaly detection on the features created

# %% [markdown]
# Before applying the transformations, a systematic approach is followed to analyze the specific characteristics of each distribution and choose the most appropriate transformation.

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from mpl_toolkits.axes_grid1.inset_locator import inset_axes

# Definizione dei gruppi tematici basati sulle features estratte dal notebook
feature_groups = {
    'Global Patient Features': [
        'total_tests', 'n_invalid', 'tests_days_span', 'perc_invalid'
    ],
    'Potassium (K) Features': [
        'k_min', 'k_max', 'k_n', 'k_abnormalratio'
    ],
    'Sodium & Chloride Features': [
        'na_min', 'na_max', 'na_n', 'na_abnormal_ratio',
        'cl_min', 'cl_max', 'cl_n', 'cl_abnormal_ratio', 'na_cl_ratio'
    ],
    'Renal Function (Creatinine)': [
        'creat_max', 'creat_n', 'creat_abnormal_ratio'
    ],
    'Glucose & Metabolic': [
        'glu_max', 'glu_n', 'glu_abnormal_ratio', 'glu_var'
    ]
}

# make global plots style
for group_name, features in feature_groups.items():
    # filter only existing features
    existing_features = [f for f in features if f in hadm_tests_full.columns]
    
    if not existing_features:
        continue
    
    # Layout: 2 columns x group
    n_cols = 2
    n_rows = (len(existing_features) + 1) // 2
    
    fig, axes = plt.subplots(n_rows, n_cols, figsize=(14, 4.5*n_rows))
    
    # handle case with single row
    if n_rows == 1:
        axes = axes.reshape(1, -1)
    
    axes = axes.flatten()
    
    for i, col in enumerate(existing_features):
        ax = axes[i]
        
        # Histogram with KDE
        sns.histplot(hadm_tests_full[col].dropna(), kde=True, bins=40, 
                    ax=ax, color='skyblue', edgecolor='black', linewidth=0.5)
        
        # Compute skewness
        skew_val = hadm_tests_full[col].skew()
        
        # skewness with title
        ax.set_title(f"{col}\nSkewness: {skew_val:.2f}", fontsize=11, pad=10)
        ax.grid(axis='y', alpha=0.3, linestyle='--')
        ax.set_xlabel('')
        
        # Boxplot inset 
        ax_ins = inset_axes(ax, width="22%", height="20%", loc='upper right')
        sns.boxplot(x=hadm_tests_full[col].dropna(), ax=ax_ins, 
                   color='gold', width=0.5, linewidth=1)
        ax_ins.set_xlabel("")
        ax_ins.set_xticks([])
        ax_ins.tick_params(labelsize=7)
    
    for j in range(i+1, len(axes)):
        axes[j].axis('off')
    
    # title and layout adjustments
    plt.suptitle(f"Distribution Analysis - {group_name} (BEFORE Transformation)", 
                fontsize=14, fontweight='bold', y=1.00)
    plt.tight_layout(rect=[0, 0, 1, 0.98])
    plt.show()
    
# Summary statistics: skewness, kurtosis, missing percentage
    for feat in existing_features:
        skew = hadm_tests_full[feat].skew()
        kurt = hadm_tests_full[feat].kurtosis()
        missing_pct = hadm_tests_full[feat].isna().mean() * 100
        print(f"{feat:25s} | Skew: {skew:6.2f} | Kurt: {kurt:6.2f} | Missing: {missing_pct:5.1f}%")
# Out:
# /tmp/ipykernel_91923/817544361.py:75: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout(rect=[0, 0, 1, 0.98])
# total_tests               | Skew:   5.39 | Kurt:  57.67 | Missing:   0.0%
# n_invalid                 | Skew:   5.86 | Kurt:  64.88 | Missing:   0.0%
# tests_days_span           | Skew:   2.79 | Kurt:  13.78 | Missing:   0.0%
# perc_invalid              | Skew:  -0.02 | Kurt:  -0.16 | Missing:   0.0%
# /tmp/ipykernel_91923/817544361.py:75: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout(rect=[0, 0, 1, 0.98])
# k_min                     | Skew:   0.01 | Kurt:   0.96 | Missing:   0.3%
# k_max                     | Skew:   1.81 | Kurt:   7.09 | Missing:   0.3%
# k_n                       | Skew:   3.95 | Kurt:  27.50 | Missing:   0.3%
# /tmp/ipykernel_91923/817544361.py:75: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout(rect=[0, 0, 1, 0.98])
# na_min                    | Skew:  -1.27 | Kurt:   3.94 | Missing:   0.4%
# na_max                    | Skew:  -0.24 | Kurt:  10.04 | Missing:   0.4%
# na_n                      | Skew:   3.87 | Kurt:  26.18 | Missing:   0.4%
# na_abnormal_ratio         | Skew:   2.98 | Kurt:   8.78 | Missing:   0.4%
# cl_min                    | Skew:  -0.84 | Kurt:   1.08 | Missing:   0.4%
# cl_max                    | Skew:   0.16 | Kurt:   3.20 | Missing:   0.4%
# cl_n                      | Skew:   3.87 | Kurt:  26.40 | Missing:   0.4%
# cl_abnormal_ratio         | Skew:   1.78 | Kurt:   2.04 | Missing:   0.4%
# na_cl_ratio               | Skew:   0.87 | Kurt:   1.52 | Missing:   0.4%
# /tmp/ipykernel_91923/817544361.py:75: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout(rect=[0, 0, 1, 0.98])
# creat_max                 | Skew:   3.82 | Kurt:  19.22 | Missing:   0.3%
# creat_n                   | Skew:   3.80 | Kurt:  25.80 | Missing:   0.3%
# creat_abnormal_ratio      | Skew:   0.40 | Kurt:  -1.68 | Missing:   0.3%
# /tmp/ipykernel_91923/817544361.py:75: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout(rect=[0, 0, 1, 0.98])
# glu_max                   | Skew:   2.37 | Kurt:   9.10 | Missing:   0.6%
# glu_n                     | Skew:   5.02 | Kurt:  47.26 | Missing:   0.6%
# glu_abnormal_ratio        | Skew:  -0.65 | Kurt:  -0.90 | Missing:   0.6%
# glu_var                   | Skew:   2.66 | Kurt:  13.05 | Missing:   8.0%

# %% [markdown]
# Defining ranges for detecting impossible clinical values for the features we've created

# %%
lab_impossible_ranges = {
    # Electrolytes (mEq/L or mmol/L)
    'kmin': (1.0, 10.0),          # Potassium: <1.0 = fatal arrhythmia, >10 = hemolysis artifact
    'kmax': (1.0, 10.0),
    'namin': (100, 200),          # Sodium: <100 = severe hyponatremia, >200 impossible
    'namax': (100, 200),
    'clmin': (50, 150),           # Chloride: <50 = severe metabolic issue, >150 rare
    'clmax': (50, 150),
    
    # Renal function
    'creatmax': (0.1, 25.0),      # Creatinine mg/dL: <0.1 = error, >25 = extreme renal failure
    
    # Glucose
    'glumax': (20, 1000),         # Glucose mg/dL: <20 = severe hypoglycemia, >1000 = DKA extreme
    'gluvar': (0, 300),           # Glucose variability (std dev)
    
    # Ratios
    'naclratio': (0.8, 1.8),      # Na/Cl ratio: typically 1.36-1.42, extremes = errors
    
    # Count variables (must be positive integers)
    'kn': (0, 500),               
    'nan': (0, 500),
    'cln': (0, 500),
    'creatn': (0, 500),
    'glun': (0, 500),
    
    # Ratios (0-1 or 0-100%)
    'percinvalid': (0, 1),
    'kabnormalratio': (0, 1),
    'naabnormalratio': (0, 1),
    'clabnormalratio': (0, 1),
    'creatabnormalratio': (0, 1),
    'gluabnormalratio': (0, 1)
}

# %%
def detect_unit_issue(data, expected_range):
    if data.isna().all():
        return 'NO_DATA'
    
    # Check if most values are outside expected range
    outside_pct = ((data < expected_range[0]) | (data > expected_range[1])).mean()
    
    if outside_pct > 0.8:  # More than 80% outside range
        return 'NEEDS_CONVERSION'
    elif outside_pct > 0.2:  # 20-80% outside
        return 'MIXED_UNITS'
    else:
        return 'OK'

# %%
# Check each lab feature
conversion_needed = {}

for feature, (min_val, max_val) in lab_impossible_ranges.items():
    if feature in hadm_tests_full.columns:
        data = hadm_tests_full[feature].dropna()
        
        if len(data) > 0:
            status = detect_unit_issue(data, (min_val, max_val))
            
            if status != 'OK' and status != 'NO_DATA':
                conversion_needed[feature] = {
                    'status': status,
                    'current_range': (data.min(), data.max()),
                    'expected_range': (min_val, max_val),
                    'mean': data.mean(),
                    'median': data.median()
                }
                
                print(f"\n {feature}:")
                print(f"    Status: {status}")
                print(f"    Current: [{data.min():.2f}, {data.max():.2f}]")
                print(f"    Expected: [{min_val}, {max_val}]")
                print(f"    Mean: {data.mean():.2f}, Median: {data.median():.2f}")

# %% [markdown]
# NO conversion neeeded (we've done before in this report)

# %% [markdown]
# Now, we remove impossible clinical values

# %%
df_lab_cleaned = hadm_tests_full.copy()
total_removed = 0
removal_log = []

for feature, (min_val, max_val) in lab_impossible_ranges.items():
    if feature in df_lab_cleaned.columns:
        mask_invalid = (df_lab_cleaned[feature] < min_val) | (df_lab_cleaned[feature] > max_val)
        n_removed = mask_invalid.sum()
        
        if n_removed > 0:
            # Show examples before removal
            examples_low = df_lab_cleaned.loc[(df_lab_cleaned[feature] < min_val), feature].head(3)
            examples_high = df_lab_cleaned.loc[(df_lab_cleaned[feature] > max_val), feature].head(3)
            
            print(f"\n {feature}:")
            print(f"    Impossible range: [{min_val}, {max_val}]")
            print(f"    Values to remove: {n_removed} ({n_removed/len(df_lab_cleaned)*100:.2f}%)")
            
            if len(examples_low) > 0:
                print(f"    Too LOW: {examples_low.tolist()}")
            if len(examples_high) > 0:
                print(f"    Too HIGH: {examples_high.tolist()}")
            
            # Remove by setting to NaN
            df_lab_cleaned.loc[mask_invalid, feature] = np.nan
            total_removed += n_removed
            
            removal_log.append({
                'Feature': feature,
                'Removed': n_removed,
                'Pct_Removed': n_removed / len(df_lab_cleaned) * 100
            })

# %%
print(f"✅ TOTAL IMPOSSIBLE VALUES REMOVED: {total_removed}")
# Out:
# ✅ TOTAL IMPOSSIBLE VALUES REMOVED: 0

# %% [markdown]
# ### Feature trasformation

# %%
columns_final = df_lab_cleaned.columns
continuous_cols_only = [c for c in columns_final if df_lab_cleaned[c].nunique() > 2]
skewness = df_lab_cleaned[continuous_cols_only].skew().sort_values(ascending=False)

# 3. Mostra chi supera la soglia di allarme (solitamente 1 o 0.75)
skewed_features = skewness[abs(skewness) > 1]
print("Strongly skewed features:")
print(skewed_features)
# Out:
# Strongly skewed features:
# na_n_abnormal        8.608948
# cl_n_abnormal        6.890042
# n_invalid            5.855090
# k_n_abnormal         5.601131
# total_tests          5.389526
# glu_n                5.020836
# glu_n_abnormal       4.950506
# creat_min            4.701162
# k_n                  3.949829
# creat_n_abnormal     3.880964
# cl_n                 3.874672
# na_n                 3.868464
# creat_max            3.821963
# creat_n              3.803698
# k_abnormal_ratio     3.662185
# na_abnormal_ratio    2.975399
# tests_days_span      2.794519
# glu_var              2.663656
# glu_min              2.619633
# glu_max              2.367427
# k_max                1.810599
# cl_abnormal_ratio    1.779711
# na_min              -1.271119
# dtype: float64

# %%
skewness = df_lab_cleaned[continuous_cols_only].skew().sort_values(ascending=False)
skewed_features = skewness[abs(skewness) > 1]
print("Strongly skewed features:")
print(skewed_features)
# Out:
# Strongly skewed features:
# na_n_abnormal        8.608948
# cl_n_abnormal        6.890042
# n_invalid            5.855090
# k_n_abnormal         5.601131
# total_tests          5.389526
# glu_n                5.020836
# glu_n_abnormal       4.950506
# creat_min            4.701162
# k_n                  3.949829
# creat_n_abnormal     3.880964
# cl_n                 3.874672
# na_n                 3.868464
# creat_max            3.821963
# creat_n              3.803698
# k_abnormal_ratio     3.662185
# na_abnormal_ratio    2.975399
# tests_days_span      2.794519
# glu_var              2.663656
# glu_min              2.619633
# glu_max              2.367427
# k_max                1.810599
# cl_abnormal_ratio    1.779711
# na_min              -1.271119
# dtype: float64

# %%
def transform_skewed_feature(series, skew_value):
    """
    features transformation based on skewness value.
    
    Regole:
    - Skew > 1 (Right-skewed): log1p() for compress right tail
    - Skew < -1 (Left-skewed): reflect + log for compress left tail
    - |Skew| <= 1: No transformation
    """
    
    transformed = series.copy()
    non_null_mask = transformed.notna()
    non_null_data = transformed[non_null_mask]
    
    if len(non_null_data) == 0:
        return transformed, 'no_transform (all NaN)'
    
    # RIGHT-SKEWED (skew > 1): long tail at right
    if skew_value > 1:
        if (non_null_data < 0).any():
            # Shift for negative values
            min_val = non_null_data.min()
            shift = abs(min_val) + 1
            transformed[non_null_mask] = np.log1p(non_null_data + shift)
            return transformed, f'log1p (shifted by {shift:.2f})'
        else:
            # log1p for data ≥0
            transformed[non_null_mask] = np.log1p(non_null_data)
            return transformed, 'log1p'
    
    # LEFT-SKEWED (skew < -1): long tail at left
    elif skew_value < -1:
        # Reflect + log
        max_val = non_null_data.max()
        reflected = max_val - non_null_data + 1
        transformed[non_null_mask] = np.log1p(reflected)
        return transformed, 'reflect + log1p'
    
    else:
        return transformed, 'no_transform'

# %%
df_transformed = df_lab_cleaned.copy()
transformation_log = []

# iterate over feature names (index) and their skew values
for feature, skew_before in skewed_features.items():
    transformed_col, transform_type = transform_skewed_feature(
        df_lab_cleaned[feature],
        skew_before
    )
    skew_after = transformed_col.skew()
    df_transformed[feature] = transformed_col
    transformation_log.append({
        'Feature': feature,
        'Skew_Before': skew_before,
        'Skew_After': skew_after,
        'Transformation': transform_type,
        'Improvement': abs(skew_before) - abs(skew_after)
    })
    print(f"\n{feature}:")
    print(f"  Skew before: {skew_before:6.2f}")
    print(f"  Skew after:  {skew_after:6.2f}")
    print(f"  Transform:   {transform_type}")
# Out:
# na_n_abnormal:
#   Skew before:   8.61
#   Skew after:    2.37
#   Transform:   log1p
#
# cl_n_abnormal:
#   Skew before:   6.89
#   Skew after:    1.59
#   Transform:   log1p
#
# n_invalid:
#   Skew before:   5.86
#   Skew after:   -0.11
#   Transform:   log1p
#
# k_n_abnormal:
#   Skew before:   5.60
#   Skew after:    2.23
#   Transform:   log1p
#
# total_tests:
#   Skew before:   5.39
#   Skew after:    0.05
#   Transform:   log1p
#
# glu_n:
#   Skew before:   5.02
#   Skew after:    0.53
#   Transform:   log1p
#
# glu_n_abnormal:
#   Skew before:   4.95
#   Skew after:    0.24
#   Transform:   log1p
#
# creat_min:
#   Skew before:   4.70
#   Skew after:    2.09
#   Transform:   log1p
#
# k_n:
#   Skew before:   3.95
#   Skew after:    0.47
#   Transform:   log1p
#
# creat_n_abnormal:
#   Skew before:   3.88
#   Skew after:    0.69
#   Transform:   log1p
#
# cl_n:
#   Skew before:   3.87
#   Skew after:    0.47
#   Transform:   log1p
#
# na_n:
#   Skew before:   3.87
#   Skew after:    0.47
#   Transform:   log1p
#
# creat_max:
#   Skew before:   3.82
#   Skew after:    1.86
#   Transform:   log1p
#
# creat_n:
#   Skew before:   3.80
#   Skew after:    0.47
#   Transform:   log1p
#
# k_abnormal_ratio:
#   Skew before:   3.66
#   Skew after:    3.03
#   Transform:   log1p
#
# na_abnormal_ratio:
#   Skew before:   2.98
#   Skew after:    2.60
#   Transform:   log1p
#
# tests_days_span:
#   Skew before:   2.79
#   Skew after:    0.08
#   Transform:   log1p
#
# glu_var:
#   Skew before:   2.66
#   Skew after:   -0.34
#   Transform:   log1p
#
# glu_min:
#   Skew before:   2.62
#   Skew after:    0.19
#   Transform:   log1p
#
# glu_max:
#   Skew before:   2.37
#   Skew after:    0.80
#   Transform:   log1p
#
# k_max:
#   Skew before:   1.81
#   Skew after:    1.05
#   Transform:   log1p
#
# cl_abnormal_ratio:
#   Skew before:   1.78
#   Skew after:    1.53
#   Transform:   log1p
#
# na_min:
#   Skew before:  -1.27
#   Skew after:    0.08
#   Transform:   reflect + log1p
# /tmp/ipykernel_91923/3737229745.py:28: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[3.71357207 3.97029191 3.36729583 ... 5.47227067 2.07944154 3.91202301]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   transformed[non_null_mask] = np.log1p(non_null_data)
# /tmp/ipykernel_91923/3737229745.py:28: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[4.38202663 5.24174702 4.41884061 ... 6.07073773 3.71357207 5.14749448]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   transformed[non_null_mask] = np.log1p(non_null_data)
# /tmp/ipykernel_91923/3737229745.py:28: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[1.09861229 1.38629436 1.09861229 ... 2.7080502  0.69314718 2.07944154]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   transformed[non_null_mask] = np.log1p(non_null_data)

# %%
skewness = df_lab_cleaned[continuous_cols_only].skew().sort_values(ascending=False)
skewed_features = skewness[abs(skewness) > 1]
print("Strongly skewed features:")
print(skewed_features)
# Out:
# Strongly skewed features:
# na_n_abnormal        8.608948
# cl_n_abnormal        6.890042
# n_invalid            5.855090
# k_n_abnormal         5.601131
# total_tests          5.389526
# glu_n                5.020836
# glu_n_abnormal       4.950506
# creat_min            4.701162
# k_n                  3.949829
# creat_n_abnormal     3.880964
# cl_n                 3.874672
# na_n                 3.868464
# creat_max            3.821963
# creat_n              3.803698
# k_abnormal_ratio     3.662185
# na_abnormal_ratio    2.975399
# tests_days_span      2.794519
# glu_var              2.663656
# glu_min              2.619633
# glu_max              2.367427
# k_max                1.810599
# cl_abnormal_ratio    1.779711
# na_min              -1.271119
# dtype: float64

# %% [markdown]
# And save the features extracted

# %%
df_lab_cleaned.to_csv(notebook_dir.parents[1] / "1" / "Features" / "laboratory_tests_features.csv", index=False)
